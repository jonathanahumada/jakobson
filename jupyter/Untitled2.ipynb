# %%
import nltk
import jakobson

# %%
mensaje = nltk.corpus.brown.words("cj22") #The Emerging Nations

r1 = nltk.corpus.brown.words("cj23") # J22	Max F. Millikan & Donald L. Blackmer, editors	The Emerging Nations
r2 = nltk.corpus.brown.words("cj24") # J24	Howard J. Parad	Preventive Casework: Problems & Implications
r3 = nltk.corpus.brown.words("cj25") # J25	Sister Claire M. Sawyer	Some Aspects of Fertility of a Tri-Racial Isolate
r4 = nltk.corpus.brown.words("cj26") # J26	Frank Lorimer	Demographic Information on Tropical Africa
r5 = nltk.corpus.brown.words("cj27") # J28	William H. Ittelson & Samuel B. Kutash, editors	Perceptual Changes in Psychopathology
r6 = nltk.corpus.brown.words("cj28") # J30	Raymond J. Corsini	Roleplaying in Business & Industry

insumos_referencia = [r1, r2, r3, r4, r5, r6]
corpora_referencia = []

# %%
for mensaje in insumos_referencia:
    for w in mensaje:
        corpora_referencia.append(w)

# %%
corpora_referencia
# Out:
# ['2',
#  ':',
#  ':',
#  'Some',
#  'of',
#  'the',
#  'major',
#  'functions',
#  'of',
#  'religion',
#  'The',
#  'place',
#  'of',
#  'religion',
#  'in',
#  'the',
#  'simple',
#  ',',
#  'preliterate',
#  'societies',
#  'is',
#  'quite',
#  'definite',
#  ';',
#  ';',
#  'as',
#  'a',
#  'complex',
#  'it',
#  'fits',
#  'into',
#  'the',
#  'whole',
#  'social',
#  'organization',
#  'and',
#  'functions',
#  'dominantly',
#  'in',
#  'every',
#  'part',
#  'of',
#  'it',
#  '.',
#  'In',
#  'societies',
#  'like',
#  'ours',
#  ',',
#  'however',
#  ',',
#  'its',
#  'place',
#  'is',
#  'less',
#  'clear',
#  'and',
#  'more',
#  'complex',
#  '.',
#  'With',
#  'the',
#  'diversity',
#  'of',
#  'religious',
#  'viewpoints',
#  ',',
#  'there',
#  'are',
#  'differences',
#  'of',
#  'opinion',
#  'as',
#  'to',
#  'the',
#  'essential',
#  'features',
#  'of',
#  'religion',
#  ';',
#  ';',
#  'and',
#  'there',
#  'are',
#  'different',
#  'opinions',
#  'as',
#  'to',
#  'the',
#  'essential',
#  'functions',
#  'of',
#  'religion',
#  '.',
#  'Nevertheless',
#  ',',
#  'for',
#  'most',
#  'of',
#  'the',
#  'population',
#  'of',
#  'heterogeneous',
#  'advanced',
#  'societies',
#  ',',
#  'though',
#  'less',
#  'for',
#  'the',
#  'less',
#  'religious',
#  'portion',
#  ',',
#  'religion',
#  'does',
#  'perform',
#  'certain',
#  'modal',
#  'individual',
#  'and',
#  'social',
#  'functions',
#  '.',
#  'Although',
#  'the',
#  'inner',
#  'functions',
#  'of',
#  'religion',
#  'are',
#  'not',
#  'of',
#  'direct',
#  'significance',
#  'in',
#  'social',
#  'organization',
#  ',',
#  'they',
#  'have',
#  'important',
#  'indirect',
#  'consequences',
#  '.',
#  'If',
#  'the',
#  'inner',
#  'functions',
#  'of',
#  'religion',
#  'are',
#  'performed',
#  ',',
#  'the',
#  'individual',
#  'is',
#  'a',
#  'composed',
#  ',',
#  'ordered',
#  ',',
#  'motivated',
#  ',',
#  'and',
#  'emotionally',
#  'secure',
#  'associate',
#  ';',
#  ';',
#  'he',
#  'is',
#  'not',
#  'greatly',
#  'frustrated',
#  ',',
#  'and',
#  'he',
#  'is',
#  'not',
#  'anomic',
#  ';',
#  ';',
#  'he',
#  'is',
#  'better',
#  'fitted',
#  'to',
#  'perform',
#  'his',
#  'social',
#  'life',
#  'among',
#  'his',
#  'fellows',
#  '.',
#  'There',
#  'are',
#  'several',
#  'closely',
#  'related',
#  'inner',
#  'functions',
#  '.',
#  'In',
#  'the',
#  'last',
#  'analysis',
#  ',',
#  'religion',
#  'is',
#  'the',
#  'means',
#  'of',
#  'inducing',
#  ',',
#  'formulating',
#  ',',
#  'expressing',
#  ',',
#  'enhancing',
#  ',',
#  'implementing',
#  ',',
#  'and',
#  'perpetuating',
#  "man's",
#  'deepest',
#  'experience',
#  '--',
#  'the',
#  'religious',
#  '.',
#  'Man',
#  'is',
#  'first',
#  'religious',
#  ';',
#  ';',
#  'the',
#  'instrumentalities',
#  'follow',
#  '.',
#  'Religion',
#  'seeks',
#  'to',
#  'satisfy',
#  'human',
#  'needs',
#  'of',
#  'great',
#  'pertinence',
#  '.',
#  'The',
#  'significant',
#  'things',
#  'in',
#  'it',
#  ',',
#  'at',
#  'the',
#  'higher',
#  'religious',
#  'levels',
#  ',',
#  'are',
#  'the',
#  'inner',
#  'emotional',
#  ',',
#  'mental',
#  ',',
#  'and',
#  'spiritual',
#  'occurrences',
#  'that',
#  'fill',
#  'the',
#  'pressing',
#  'human',
#  'needs',
#  'of',
#  'self-preservation',
#  ',',
#  'self-pacification',
#  ',',
#  'and',
#  'self-completion',
#  '.',
#  'The',
#  'chief',
#  'experience',
#  'is',
#  'the',
#  'sensing',
#  'of',
#  'communion',
#  ',',
#  'and',
#  'in',
#  'the',
#  'higher',
#  'religions',
#  ',',
#  'of',
#  'a',
#  'harmonious',
#  'relationship',
#  'with',
#  'the',
#  'supernatural',
#  'power',
#  '.',
#  'Related',
#  'to',
#  'this',
#  'is',
#  'the',
#  'fact',
#  'that',
#  'most',
#  'of',
#  'the',
#  'higher',
#  'religions',
#  'define',
#  'for',
#  'the',
#  'individual',
#  'his',
#  'place',
#  'in',
#  'the',
#  'universe',
#  'and',
#  'give',
#  'him',
#  'a',
#  'feeling',
#  'that',
#  'he',
#  'is',
#  'relatively',
#  'secure',
#  'in',
#  'an',
#  'ordered',
#  ',',
#  'dependable',
#  'universe',
#  '.',
#  'Man',
#  'has',
#  'the',
#  'experience',
#  'of',
#  'being',
#  'helpfully',
#  'allied',
#  'with',
#  'what',
#  'he',
#  'cannot',
#  'fully',
#  'understand',
#  ';',
#  ';',
#  'he',
#  'is',
#  'a',
#  'coordinate',
#  'part',
#  'of',
#  'all',
#  'of',
#  'the',
#  'mysterious',
#  'energy',
#  'and',
#  'being',
#  'and',
#  'movement',
#  '.',
#  'The',
#  'universe',
#  'is',
#  'a',
#  'safe',
#  'and',
#  'permanent',
#  'home',
#  '.',
#  'A',
#  'number',
#  'of',
#  'religions',
#  'also',
#  'satisfy',
#  'for',
#  'many',
#  'the',
#  'need',
#  'of',
#  'being',
#  'linked',
#  'with',
#  'the',
#  'ultimate',
#  'and',
#  'eternal',
#  '.',
#  'Death',
#  'is',
#  'not',
#  'permanent',
#  'defeat',
#  'and',
#  'disappearance',
#  ';',
#  ';',
#  'man',
#  'has',
#  'a',
#  'second',
#  'chance',
#  '.',
#  'He',
#  'is',
#  'not',
#  'lost',
#  'in',
#  'the',
#  'abyss',
#  'of',
#  'endless',
#  'time',
#  ';',
#  ';',
#  'he',
#  'has',
#  'endless',
#  'being',
#  '.',
#  'Religion',
#  'at',
#  'its',
#  'best',
#  'also',
#  'offers',
#  'the',
#  'experience',
#  'of',
#  'spiritual',
#  'fulfillment',
#  'by',
#  'inviting',
#  'man',
#  'into',
#  'the',
#  'highest',
#  'realm',
#  'of',
#  'the',
#  'spirit',
#  '.',
#  'Religion',
#  'can',
#  'summate',
#  ',',
#  'epitomize',
#  ',',
#  'relate',
#  ',',
#  'and',
#  'conserve',
#  'all',
#  'the',
#  'highest',
#  'ideals',
#  'and',
#  'values',
#  '--',
#  'ethical',
#  ',',
#  'aesthetic',
#  ',',
#  'and',
#  'religious',
#  '--',
#  'of',
#  'man',
#  'formed',
#  'in',
#  'his',
#  'culture',
#  '.',
#  'There',
#  'is',
#  'also',
#  'the',
#  'possibility',
#  ',',
#  'among',
#  'higher',
#  'religions',
#  ',',
#  'of',
#  'experiencing',
#  'consistent',
#  'meaning',
#  'in',
#  'life',
#  'and',
#  'enjoying',
#  'guidance',
#  'and',
#  'expansiveness',
#  '.',
#  'The',
#  'kind',
#  'of',
#  'religious',
#  'experience',
#  'that',
#  'most',
#  'moderns',
#  'seek',
#  'not',
#  'only',
#  'provides',
#  ',',
#  'clarifies',
#  ',',
#  'and',
#  'relates',
#  'human',
#  'yearnings',
#  ',',
#  'values',
#  ',',
#  'ideals',
#  ',',
#  'and',
#  'purposes',
#  ';',
#  ';',
#  'it',
#  'also',
#  'provides',
#  'facilities',
#  'and',
#  'incitements',
#  'for',
#  'the',
#  'development',
#  'of',
#  'personality',
#  ',',
#  'sociality',
#  ',',
#  'and',
#  'creativeness',
#  '.',
#  'Under',
#  'the',
#  'religious',
#  'impulse',
#  ',',
#  'whether',
#  'theistic',
#  'or',
#  'humanistic',
#  ',',
#  'men',
#  'have',
#  'joy',
#  'in',
#  'living',
#  ';',
#  ';',
#  'life',
#  'leads',
#  'somewhere',
#  '.',
#  'Religion',
#  'at',
#  'its',
#  'best',
#  'is',
#  'out',
#  'in',
#  'front',
#  ',',
#  'ever',
#  'beckoning',
#  'and',
#  'leading',
#  'on',
#  ',',
#  'and',
#  ',',
#  'as',
#  'Lippman',
#  'put',
#  'it',
#  ',',
#  '``',
#  'mobilizing',
#  'all',
#  "man's",
#  'scattered',
#  'energies',
#  'in',
#  'one',
#  'triumphant',
#  'sense',
#  'of',
#  'his',
#  'own',
#  'infinite',
#  'importance',
#  "''",
#  '.',
#  'At',
#  'the',
#  'same',
#  'time',
#  'that',
#  'religion',
#  'binds',
#  'the',
#  'individual',
#  'helpfully',
#  'to',
#  'the',
#  'supernatural',
#  'and',
#  'gives',
#  'him',
#  'cosmic',
#  'peace',
#  'and',
#  'a',
#  'sense',
#  'of',
#  'supreme',
#  'fulfillment',
#  ',',
#  'it',
#  'also',
#  'has',
#  'great',
#  'therapeutic',
#  'value',
#  'for',
#  'him',
#  '.',
#  'It',
#  'gives',
#  'him',
#  'aid',
#  ',',
#  'comfort',
#  ',',
#  'even',
#  'solace',
#  ',',
#  'in',
#  'meeting',
#  'mundane',
#  'life',
#  'situations',
#  'where',
#  'his',
#  'own',
#  'unassisted',
#  'practical',
#  'knowledge',
#  'and',
#  'skill',
#  'are',
#  'felt',
#  'by',
#  'him',
#  'to',
#  'be',
#  'inadequate',
#  '.',
#  'He',
#  'is',
#  'confronted',
#  'with',
#  'the',
#  'recurrent',
#  'crises',
#  ',',
#  'such',
#  'as',
#  'great',
#  'natural',
#  'catastrophes',
#  'and',
#  'the',
#  'great',
#  'transitions',
#  'of',
#  'life',
#  '--',
#  'marriage',
#  ',',
#  'incurable',
#  'disease',
#  ',',
#  'widowhood',
#  ',',
#  'old',
#  'age',
#  ',',
#  'the',
#  'certainty',
#  'of',
#  'death',
#  '.',
#  'He',
#  'has',
#  'to',
#  'cope',
#  'with',
#  'frustration',
#  'and',
#  'other',
#  'emotional',
#  'disturbance',
#  'and',
#  'anomie',
#  '.',
#  'His',
#  'religious',
#  'beliefs',
#  'provide',
#  'him',
#  'with',
#  'plausible',
#  'explanations',
#  'for',
#  'many',
#  'conditions',
#  'which',
#  'cause',
#  'him',
#  'great',
#  'concern',
#  ',',
#  'and',
#  'his',
#  'religious',
#  'faith',
#  'makes',
#  'possible',
#  'fortitude',
#  ',',
#  'equanimity',
#  ',',
#  'and',
#  'consolation',
#  ',',
#  'enabling',
#  'him',
#  'to',
#  'endure',
#  'colossal',
#  'misfortune',
#  ',',
#  'fear',
#  ',',
#  'frustration',
#  ',',
#  'uncertainty',
#  ',',
#  'suffering',
#  ',',
#  'evil',
#  ',',
#  'and',
#  'danger',
#  '.',
#  'Religion',
#  'usually',
#  'also',
#  'includes',
#  'a',
#  'principle',
#  'of',
#  'compensation',
#  ',',
#  'mainly',
#  'in',
#  'a',
#  'promised',
#  'perfect',
#  'future',
#  'state',
#  '.',
#  'The',
#  'belief',
#  'in',
#  'immortality',
#  ',',
#  'where',
#  'held',
#  ',',
#  'functions',
#  'as',
#  'a',
#  'redress',
#  'for',
#  'the',
#  'ills',
#  'and',
#  'disappointments',
#  'of',
#  'the',
#  'here',
#  'and',
#  'now',
#  '.',
#  'The',
#  'tensions',
#  'accompanying',
#  'a',
#  'repressive',
#  'consciousness',
#  'of',
#  'wrongdoing',
#  'or',
#  'sinning',
#  'or',
#  'some',
#  'tormenting',
#  'secret',
#  'are',
#  'relieved',
#  'for',
#  'the',
#  'less',
#  'self-contained',
#  'or',
#  'self-sufficient',
#  'by',
#  'confession',
#  ',',
#  'repentance',
#  ',',
#  'and',
#  'penance',
#  '.',
#  'The',
#  'feeling',
#  'of',
#  'individual',
#  'inferiority',
#  ',',
#  'defeat',
#  ',',
#  'or',
#  'humilation',
#  'growing',
#  'out',
#  'of',
#  'various',
#  'social',
#  'situations',
#  'or',
#  'individual',
#  'deficiencies',
#  'or',
#  'failures',
#  'is',
#  'compensated',
#  'for',
#  'by',
#  'communion',
#  'in',
#  'worship',
#  'or',
#  'prayer',
#  'with',
#  'a',
#  'friendly',
#  ',',
#  'but',
#  'all-victorious',
#  'Father-God',
#  ',',
#  'as',
#  'well',
#  'as',
#  'by',
#  'sympathetic',
#  'fellowship',
#  'with',
#  'others',
#  'who',
#  'share',
#  'this',
#  'faith',
#  ',',
#  'and',
#  'by',
#  'opportunities',
#  'in',
#  'religious',
#  'acts',
#  'for',
#  'giving',
#  'vent',
#  'to',
#  'emotions',
#  'and',
#  'energies',
#  '.',
#  'In',
#  'providing',
#  'for',
#  'these',
#  'inner',
#  'individual',
#  'functions',
#  ',',
#  'religion',
#  'undertakes',
#  'in',
#  'behalf',
#  'of',
#  'individual',
#  'peace',
#  'of',
#  'mind',
#  'and',
#  'well-being',
#  'services',
#  'for',
#  'which',
#  'there',
#  'is',
#  'no',
#  'other',
#  'institution',
#  '.',
#  'In',
#  'addition',
#  'to',
#  'the',
#  'functions',
#  'of',
#  'religion',
#  'within',
#  'man',
#  ',',
#  'there',
#  'have',
#  'always',
#  'been',
#  'the',
#  'outer',
#  'social',
#  'functions',
#  'for',
#  'the',
#  'community',
#  'and',
#  'society',
#  '.',
#  'The',
#  'two',
#  'have',
#  'never',
#  'been',
#  'separable',
#  '.',
#  'Religion',
#  'is',
#  'vitally',
#  'necessary',
#  'in',
#  'both',
#  'societal',
#  'maintenance',
#  'and',
#  'regulation',
#  '.',
#  'The',
#  'value-system',
#  'of',
#  'a',
#  'community',
#  'or',
#  'society',
#  'is',
#  'always',
#  ...]

# %% [markdown]
# Antes de obtener el *indice metafórico* se hacen calculos preliminares.

# %%
jakobson.matriz_semantica(mensaje)
# Out:
# {'recreated': ['renovate',
#   'revivify',
#   'recreate',
#   'vivify',
#   'cheer',
#   'embolden',
#   'reanimate',
#   'animate',
#   'hearten',
#   'repair',
#   'revive',
#   'play',
#   'quicken'],
#  'provincial': ['bucolic', 'peasant', 'provincial'],
#  'reforms': ['regenerate',
#   'straighten_out',
#   'rectify',
#   'reclaim',
#   'reform',
#   'see_the_light'],
#  'vastly': ['immensely', 'vastly'],
#  'change': ['shift',
#   'switch',
#   'change',
#   'modification',
#   'deepen',
#   'modify',
#   'exchange',
#   'transfer',
#   'alteration',
#   'alter',
#   'convert',
#   'commute',
#   'vary',
#   'variety',
#   'interchange'],
#  'showing': ['designate',
#   'showing',
#   'register',
#   'shew',
#   'viewing',
#   'bear_witness',
#   'demo',
#   'show',
#   'screening',
#   'prove',
#   'present',
#   'exhibit',
#   'depict',
#   'evince',
#   'evidence',
#   'demonstrate',
#   'indicate',
#   'record',
#   'express',
#   'picture',
#   'testify',
#   'read',
#   'render',
#   'establish',
#   'usher',
#   'display',
#   'show_up',
#   'point'],
#  'modernization': ['modernisation', 'modernization'],
#  'mature': ['grow',
#   'fledged',
#   'get_on',
#   'ripe',
#   'ripen',
#   'matured',
#   'mature',
#   'maturate',
#   'senesce',
#   'suppurate',
#   'age'],
#  'comprehensive': ['comp', 'comprehensive_examination', 'comprehensive'],
#  'which': [],
#  'promoting': ['advertise',
#   'promote',
#   'upgrade',
#   'advertize',
#   'boost',
#   'elevate',
#   'push',
#   'encourage',
#   'advance',
#   'raise',
#   'kick_upstairs',
#   'further'],
#  'education': ['teaching',
#   'training',
#   'Education',
#   'didactics',
#   'educational_activity',
#   'Department_of_Education',
#   'education',
#   'pedagogy',
#   'Education_Department',
#   'instruction',
#   'breeding'],
#  'responsible': ['responsible_for', 'creditworthy', 'responsible'],
#  'democratize': ['democratise', 'democratize'],
#  'modern': ['advanced',
#   'Modern',
#   'forward-looking',
#   'innovative',
#   'modern_font',
#   'New',
#   'Bodoni_font',
#   'Bodoni',
#   'modern',
#   'mod',
#   'modernistic'],
#  'telling': ['weighty',
#   'singing',
#   'recount',
#   'severalise',
#   'revealing',
#   'order',
#   'severalize',
#   'telling',
#   'impressive',
#   'apprisal',
#   'notification',
#   'secern',
#   'tell',
#   'recounting',
#   'tattle',
#   'cogent',
#   'tell_apart',
#   'recite',
#   'evidence',
#   'narrate',
#   'separate',
#   'enjoin',
#   'say',
#   'distinguish',
#   'assure',
#   'relation',
#   'state',
#   'differentiate',
#   'secernate',
#   'telltale'],
#  'world': ['human_race',
#   'Earth',
#   'world-wide',
#   'world',
#   'public',
#   'reality',
#   'humankind',
#   'worldly_concern',
#   'global',
#   'domain',
#   'existence',
#   'earth',
#   'cosmos',
#   'humanity',
#   'creation',
#   'humans',
#   'globe',
#   'human_beings',
#   'earthly_concern',
#   'macrocosm',
#   'worldwide',
#   'populace',
#   'universe',
#   'man',
#   'mankind',
#   'planetary'],
#  'concerted': ['cooperative',
#   'concert',
#   'conjunct',
#   'conjunctive',
#   'concerted'],
#  'an': ['AN', 'Associate_in_Nursing'],
#  'part': ['contribution',
#   'start',
#   'disunite',
#   'office',
#   'take_off',
#   'persona',
#   'partly',
#   'set_forth',
#   'partially',
#   'component',
#   'part',
#   'percentage',
#   'component_part',
#   'break',
#   'split_up',
#   'set_off',
#   'constituent',
#   'section',
#   'divide',
#   'function',
#   'division',
#   'voice',
#   'separate',
#   'split',
#   'start_out',
#   'share',
#   'break_up',
#   'character',
#   'role',
#   'theatrical_role',
#   'parting',
#   'depart',
#   'piece',
#   'region',
#   'portion',
#   'set_out'],
#  'democratic': ['popular', 'democratic', 'Democratic'],
#  'As': ['angstrom_unit',
#   'every_bit',
#   'AS',
#   'atomic_number_33',
#   'Eastern_Samoa',
#   'As',
#   'equally',
#   'vitamin_A',
#   'American_Samoa',
#   'as',
#   'axerophthol',
#   'antiophthalmic_factor',
#   'A',
#   'arsenic',
#   'group_A',
#   'deoxyadenosine_monophosphate',
#   'adenine',
#   'amp',
#   'a',
#   'angstrom',
#   'type_A',
#   'ampere'],
#  'divisive': ['divisive', 'factious', 'dissentious'],
#  'readiness': ['forwardness',
#   'set',
#   'preparedness',
#   'readiness',
#   'preparation',
#   'zeal',
#   'eagerness',
#   'facility'],
#  'characterize': ['characterize', 'characterise', 'qualify'],
#  'plan': ['program',
#   'plan',
#   'design',
#   'be_after',
#   'contrive',
#   'project',
#   'architectural_plan',
#   'programme'],
#  'appraise': ['measure',
#   'value',
#   'appraise',
#   'assess',
#   'evaluate',
#   'survey',
#   'valuate'],
#  'patience': ['solitaire', 'forbearance', 'patience', 'longanimity'],
#  'illusions': ['conjuration',
#   'phantasy',
#   'magic_trick',
#   'illusion',
#   'legerdemain',
#   'magic',
#   'semblance',
#   'conjuring_trick',
#   'thaumaturgy',
#   'fancy',
#   'fantasy',
#   'delusion',
#   'head_game',
#   'deception',
#   'trick'],
#  'when': [],
#  'assume': ['take_on',
#   'accept',
#   'simulate',
#   'get_into',
#   'arrogate',
#   'wear',
#   'assume',
#   'strike',
#   'bear',
#   'take_up',
#   'take',
#   'acquire',
#   'feign',
#   'take_over',
#   'presume',
#   'don',
#   'adopt',
#   'usurp',
#   'take_for_granted',
#   'sham',
#   'put_on',
#   'seize'],
#  'forms': ['imprint',
#   'contour',
#   'constitute',
#   'configuration',
#   'forge',
#   'soma',
#   'manikin',
#   'take_form',
#   'build',
#   'chassis',
#   'signifier',
#   'shape',
#   'cast',
#   'mould',
#   'kind',
#   'descriptor',
#   'grade',
#   'var.',
#   'organise',
#   'physical_body',
#   'frame',
#   'word_form',
#   'make',
#   'take_shape',
#   'conformation',
#   'form',
#   'sort',
#   'bod',
#   'class',
#   'variety',
#   'manakin',
#   'spring',
#   'course',
#   'material_body',
#   'organize',
#   'mold',
#   'figure',
#   'human_body',
#   'flesh',
#   'mannikin',
#   'work',
#   'mannequin',
#   'variant',
#   'strain',
#   'physique',
#   'anatomy',
#   'pattern',
#   'phase'],
#  'waters': ['pee',
#   'amnionic_fluid',
#   'H2O',
#   'irrigate',
#   'body_of_water',
#   'piddle',
#   'weewee',
#   'water',
#   'water_system',
#   'water_supply',
#   'Ethel_Waters',
#   'urine',
#   'Waters',
#   'amniotic_fluid',
#   'piss',
#   'waters'],
#  'condition': ['circumstance',
#   'condition',
#   'consideration',
#   'status',
#   'shape',
#   'discipline',
#   'term',
#   'check',
#   'precondition',
#   'specify',
#   'stipulation',
#   'experimental_condition',
#   'qualify',
#   'stipulate',
#   'train'],
#  'relationship': ['family_relationship',
#   'relationship',
#   'human_relationship',
#   'kinship'],
#  'purchased': ['purchase', 'buy'],
#  'sectors': ['sphere', 'sector'],
#  'seriously': ['severely',
#   'seriously',
#   'earnestly',
#   'in_earnest',
#   'badly',
#   'gravely'],
#  'toward': [],
#  'Philippines': ['Philippines',
#   'Philippine_Islands',
#   'Republic_of_the_Philippines',
#   'Filipino',
#   'Philippine'],
#  'competence': ['competence', 'competency'],
#  'troubled': ['trouble',
#   'turbulent',
#   'inconvenience_oneself',
#   'disoblige',
#   'tumultuous',
#   'trouble_oneself',
#   'inconvenience',
#   'riotous',
#   'discommode',
#   'incommode',
#   'ail',
#   'distract',
#   'perturb',
#   'bother',
#   'put_out',
#   'upset',
#   'unhinge',
#   'troubled',
#   'disquiet',
#   'disorder',
#   'cark',
#   'pain',
#   'disturb',
#   'disruptive'],
#  'make': ['wee',
#   'constitute',
#   'prepare',
#   'pee-pee',
#   'have',
#   'get_to',
#   'attain',
#   'cook',
#   'spend_a_penny',
#   'cause',
#   'create',
#   'shit',
#   'name',
#   'brand',
#   'build',
#   'throw',
#   'fix',
#   'make_up',
#   'stool',
#   'score',
#   'piddle',
#   'arrive_at',
#   'realise',
#   'puddle',
#   'wee-wee',
#   'pass_water',
#   'construct',
#   'ready',
#   'shuffle',
#   'take_in',
#   'defecate',
#   'urinate',
#   'seduce',
#   'induce',
#   'nominate',
#   'hold',
#   'ca-ca',
#   'lay_down',
#   'draw',
#   'do',
#   'bring_in',
#   'take',
#   'take_a_shit',
#   'make',
#   'take_a_crap',
#   'give',
#   'stimulate',
#   'realize',
#   'pretend',
#   'shuffling',
#   'form',
#   'make_believe',
#   'crap',
#   'earn',
#   'reach',
#   'pull_in',
#   'progress_to',
#   'micturate',
#   'relieve_oneself',
#   'clear',
#   'pee',
#   'gain',
#   'hit',
#   'take_a_leak',
#   'work',
#   'establish',
#   'get',
#   'produce',
#   'piss',
#   'make_water'],
#  'action': ['sue',
#   'fulfill',
#   'carry_out',
#   'natural_process',
#   'carry_through',
#   'fulfil',
#   'action_at_law',
#   'action',
#   'process',
#   'action_mechanism',
#   'activity',
#   'litigate',
#   'legal_action',
#   'military_action',
#   'activeness',
#   'accomplish',
#   'natural_action',
#   'execute'],
#  'economic': ['economic', 'economical'],
#  'modernize': ['modernise', 'develop', 'overhaul', 'modernize'],
#  'basic': ['staple', 'basic', 'canonic', 'canonical', 'BASIC', 'introductory'],
#  'politics': ['political_sympathies',
#   'politics',
#   'political_relation',
#   'political_science',
#   'government'],
#  'performance': ['carrying_into_action',
#   'execution',
#   'functioning',
#   'carrying_out',
#   'performance',
#   'operation',
#   'public_presentation'],
#  'dominance': ['ascendency',
#   'authority',
#   'say-so',
#   'ascendancy',
#   'ascendence',
#   'laterality',
#   'ascendance',
#   'dominance',
#   'authorization',
#   'authorisation',
#   'control',
#   'potency'],
#  'push': ['press',
#   'thrust',
#   'pushing',
#   'agitate',
#   'button',
#   'drive',
#   'labor',
#   'force',
#   'labour',
#   'crusade',
#   'push',
#   'crowd',
#   'energy',
#   'campaign',
#   'tug',
#   'advertise',
#   'bear_on',
#   'advertize',
#   'promote',
#   'fight',
#   'get-up-and-go',
#   'push_button'],
#  'choose': ['select', 'pick_out', 'take', 'prefer', 'opt', 'choose'],
#  'state': ['state_of_matter',
#   'body_politic',
#   'land',
#   'State_Department',
#   'tell',
#   'Department_of_State',
#   'res_publica',
#   'country',
#   'province',
#   'posit',
#   'United_States_Department_of_State',
#   'say',
#   'express',
#   'state',
#   'put_forward',
#   'submit',
#   'commonwealth',
#   'State',
#   'DoS',
#   'nation'],
#  'announced': ['proclaimed',
#   'harbinger',
#   'declare',
#   'annunciate',
#   'denote',
#   'foretell',
#   'announce',
#   'herald',
#   'announced'],
#  'time': ['prison_term',
#   'clock',
#   'clip',
#   'metre',
#   'sentence',
#   'meter',
#   'clock_time',
#   'time',
#   'fourth_dimension'],
#  'training': ['develop',
#   'cultivate',
#   'school',
#   'prepare',
#   'preparation',
#   'education',
#   'train',
#   'take_aim',
#   'breeding',
#   'aim',
#   'discipline',
#   'trail',
#   'civilise',
#   'groom',
#   'direct',
#   'condition',
#   'coach',
#   'grooming',
#   'take',
#   'rail',
#   'civilize',
#   'training',
#   'check',
#   'educate'],
#  'they': [],
#  'generate': ['return',
#   'beget',
#   'generate',
#   'yield',
#   'render',
#   'engender',
#   'bring_forth',
#   'give',
#   'get',
#   'father',
#   'mother',
#   'sire'],
#  'Several': ['various', 'respective', 'several'],
#  'general': ['full_general',
#   'worldwide',
#   'oecumenical',
#   'ecumenical',
#   'general',
#   'universal',
#   'world-wide',
#   'superior_general',
#   'cosmopolitan'],
#  'ahead': ['beforehand',
#   'out_front',
#   'before',
#   'onward',
#   'ahead',
#   'in_front',
#   'forrader',
#   'leading',
#   'in_advance',
#   'forward',
#   'forwards',
#   'onwards',
#   'in_the_lead'],
#  'by': ['past', 'away', 'aside', 'by'],
#  'fail': ['give_way',
#   'go_bad',
#   'die',
#   'neglect',
#   'go',
#   'flunk',
#   'go_wrong',
#   'betray',
#   'break',
#   'run_out',
#   'flush_it',
#   'give_out',
#   'conk_out',
#   'miscarry',
#   'bomb',
#   'fail',
#   'break_down'],
#  'monopoly': ['Monopoly', 'monopoly'],
#  'ways': ['style',
#   'slipway',
#   'way_of_life',
#   'path',
#   'room',
#   'means',
#   'way',
#   'agency',
#   'direction',
#   'fashion',
#   'shipway',
#   'mode',
#   'manner',
#   'elbow_room',
#   'ways'],
#  'States': ['state_of_matter',
#   'body_politic',
#   'land',
#   'State_Department',
#   'tell',
#   'Department_of_State',
#   'res_publica',
#   'country',
#   'province',
#   'posit',
#   'United_States_Department_of_State',
#   'say',
#   'express',
#   'state',
#   'put_forward',
#   'submit',
#   'commonwealth',
#   'State',
#   'DoS',
#   'nation'],
#  'more': ['more',
#   'More',
#   'more_than',
#   'to_a_greater_extent',
#   'Sir_Thomas_More',
#   'Thomas_More'],
#  'fields': ['bailiwick',
#   'area',
#   'study',
#   'field_of_force',
#   'landing_field',
#   'battlefield',
#   'W._C._Fields',
#   'field_of_view',
#   'subject',
#   'theatre_of_operations',
#   'Fields',
#   'arena',
#   'field_of_operations',
#   'field_of_honor',
#   'orbit',
#   'theater',
#   'line_of_business',
#   'discipline',
#   'subject_area',
#   'athletic_field',
#   'champaign',
#   'domain',
#   'field_of_battle',
#   'plain',
#   'William_Claude_Dukenfield',
#   'force_field',
#   'sphere',
#   'theatre',
#   'field_of_study',
#   'theater_of_operations',
#   'field',
#   'airfield',
#   'flying_field',
#   'playing_field',
#   'subject_field',
#   'playing_area',
#   'battleground',
#   'field_of_operation'],
#  'We': [],
#  'respond': ['answer', 'react', 'respond', 'reply'],
#  'treaty-making': [],
#  'not': ['non', 'not'],
#  'framework': ['framework', 'theoretical_account', 'model', 'fabric'],
#  'authoritarian': ['dictator',
#   'autocratic',
#   'authoritarian',
#   'tyrannic',
#   'tyrannical',
#   'dictatorial',
#   'despotic',
#   'overbearing'],
#  'concern': ['touch',
#   'interest',
#   'business_organization',
#   'worry',
#   'business_organisation',
#   'have-to_doe_with',
#   'occupy',
#   'concern',
#   'headache',
#   'vexation',
#   'refer',
#   'come_to',
#   'business_concern',
#   'relate',
#   'bear_on',
#   'fear',
#   'business',
#   'pertain',
#   'care',
#   'touch_on'],
#  'career': ['calling', 'career', 'vocation', 'life_history'],
#  'Burma': ['Burma', 'Union_of_Burma', 'Myanmar'],
#  'potentialities': ['potential',
#   'capability',
#   'potentiality',
#   'potency',
#   'capableness'],
#  'emphasized': ['accentuate',
#   'punctuate',
#   'emphasized',
#   'stress',
#   'emphasise',
#   'underline',
#   'emphasised',
#   'accent',
#   'underscore',
#   'emphatic',
#   'emphasize'],
#  'frank': ['candid',
#   'forthright',
#   'free-spoken',
#   'hot_dog',
#   'outspoken',
#   'frank',
#   'dog',
#   'blunt',
#   'weenie',
#   'point-blank',
#   'wienerwurst',
#   'Frank',
#   'postmark',
#   'straight-from-the-shoulder',
#   'wiener',
#   'hotdog',
#   'frankfurter',
#   'plainspoken'],
#  'policies': ['insurance', 'insurance_policy', 'policy'],
#  'made': ['wee',
#   'constitute',
#   'prepare',
#   'pee-pee',
#   'have',
#   'get_to',
#   'attain',
#   'cook',
#   'spend_a_penny',
#   'cause',
#   'create',
#   'shit',
#   'name',
#   'build',
#   'throw',
#   'fix',
#   'score',
#   'make_up',
#   'stool',
#   'piddle',
#   'arrive_at',
#   'realise',
#   'puddle',
#   'wee-wee',
#   'pass_water',
#   'construct',
#   'ready',
#   'take_in',
#   'defecate',
#   'urinate',
#   'seduce',
#   'induce',
#   'nominate',
#   'hold',
#   'made',
#   'ca-ca',
#   'lay_down',
#   'draw',
#   'do',
#   'bring_in',
#   'take',
#   'take_a_shit',
#   'make',
#   'take_a_crap',
#   'give',
#   'stimulate',
#   'realize',
#   'pretend',
#   'form',
#   'make_believe',
#   'micturate',
#   'crap',
#   'earn',
#   'reach',
#   'pull_in',
#   'progress_to',
#   'relieve_oneself',
#   'clear',
#   'pee',
#   'gain',
#   'hit',
#   'take_a_leak',
#   'work',
#   'establish',
#   'get',
#   'produce',
#   'piss',
#   'make_water'],
#  'much': ['very_much',
#   'a_lot',
#   'practically',
#   'lots',
#   'often',
#   'a_great_deal',
#   'much',
#   'a_good_deal'],
#  'expect': ['ask',
#   'look',
#   'await',
#   'wait',
#   'gestate',
#   'carry',
#   'have_a_bun_in_the_oven',
#   'anticipate',
#   'expect',
#   'require',
#   'bear'],
#  'some': ['just_about',
#   'about',
#   'more_or_less',
#   'approximately',
#   'or_so',
#   'around',
#   'roughly',
#   'close_to',
#   'some'],
#  'it': ['information_technology', 'IT'],
#  'possible': ['potential', 'possible'],
#  'progress': ['procession',
#   'move_on',
#   'pass_on',
#   'progression',
#   'build',
#   'advance',
#   'shape_up',
#   'go_on',
#   'march_on',
#   'forward_motion',
#   'progress',
#   'onward_motion',
#   'come_on',
#   'get_on',
#   'advancement',
#   'get_along',
#   'come_along',
#   'work_up',
#   'build_up'],
#  'seeking': ['seeking',
#   'search',
#   'assay',
#   'essay',
#   'try',
#   'attempt',
#   'quest',
#   'seek',
#   'look_for'],
#  'self-sustaining': ['self-sufficing', 'self-sustaining', 'self-sufficient'],
#  'highest': ['in_high_spirits',
#   'gamy',
#   'mellow',
#   'high',
#   'gamey',
#   'high-pitched',
#   'eminent'],
#  'inducing': ['induct',
#   'rush',
#   'inducement',
#   'have',
#   'bring_on',
#   'inducing',
#   'induce',
#   'cause',
#   'make',
#   'hasten',
#   'get',
#   'stimulate'],
#  'maintaining': ['sustain',
#   'wield',
#   'observe',
#   'preserve',
#   'conserve',
#   'assert',
#   'asseverate',
#   'uphold',
#   'exert',
#   'defend',
#   'hold',
#   'keep',
#   'keep_up',
#   'maintain'],
#  'fully': ['to_the_full', 'full', 'in_full', 'fully', 'amply'],
#  'supplemented': ['add_on', 'supplement', 'append', 'affix'],
#  'deal': ['distribute',
#   'administer',
#   'hand',
#   'plow',
#   'address',
#   'softwood',
#   'tidy_sum',
#   'grapple',
#   'deal_out',
#   'dish_out',
#   'trade',
#   'allot',
#   'peck',
#   'cope',
#   'mickle',
#   'conduct',
#   'cover',
#   'plenty',
#   'pile',
#   'carry_on',
#   'raft',
#   'mete_out',
#   'passel',
#   'hatful',
#   'bargain',
#   'lot',
#   'heap',
#   'batch',
#   'contend',
#   'slew',
#   'dole_out',
#   'handle',
#   'dispense',
#   'shell_out',
#   'divvy_up',
#   'great_deal',
#   'spate',
#   'treat',
#   'take',
#   'get_by',
#   'sell',
#   'share',
#   'business_deal',
#   'deal',
#   'mountain',
#   'good_deal',
#   'wad',
#   'stack',
#   'consider',
#   'parcel_out',
#   'mint',
#   'mass',
#   'quite_a_little',
#   'apportion',
#   'muckle',
#   'flock',
#   'make_out',
#   'make_do',
#   'portion_out',
#   'look_at',
#   'manage',
#   'pot',
#   'sight',
#   'care',
#   'mess'],
#  'capacity': ['electrical_capacity',
#   'content',
#   'capacitance',
#   'mental_ability',
#   'capability',
#   'capacity'],
#  'balanced': ['equilibrize',
#   'balance',
#   'balanced',
#   'equilibrate',
#   'poise',
#   'equilibrise'],
#  'effected': ['established',
#   'accomplished',
#   'effect',
#   'effectuate',
#   'set_up',
#   'effected'],
#  'tremendous': ['rattling',
#   'terrible',
#   'howling',
#   'terrific',
#   'enormous',
#   'marvellous',
#   'frightful',
#   'wonderful',
#   'fantastic',
#   'marvelous',
#   'awful',
#   'grand',
#   'wondrous',
#   'tremendous'],
#  'numbers': ['routine',
#   'Book_of_Numbers',
#   'amount',
#   'numbers_pool',
#   'total',
#   'turn',
#   'act',
#   'numeral',
#   'numerate',
#   'number',
#   'list',
#   'identification_number',
#   'count',
#   'numbers_game',
#   'bit',
#   'add_up',
#   'telephone_number',
#   'Numbers',
#   'numbers_racket',
#   'keep_down',
#   'numbers',
#   'figure',
#   'enumerate',
#   'issue',
#   'come',
#   'phone_number'],
#  'cases': ['lawsuit',
#   'cause',
#   'causa',
#   'subject',
#   'example',
#   "compositor's_case",
#   'incase',
#   'case',
#   'font',
#   'typeface',
#   'eccentric',
#   'pillowcase',
#   'guinea_pig',
#   'face',
#   'display_case',
#   'instance',
#   'vitrine',
#   'type',
#   'character',
#   'encase',
#   'caseful',
#   'event',
#   'grammatical_case',
#   'slip',
#   'pillow_slip',
#   "typesetter's_case",
#   'showcase',
#   'shell',
#   'fount',
#   'sheath',
#   'suit',
#   'casing'],
#  'untouched': ['uninfluenced',
#   'untouched',
#   'unaffected',
#   'unmoved',
#   'untasted',
#   'unswayed'],
#  'years': ['yr',
#   'old_age',
#   'days',
#   'years',
#   'geezerhood',
#   'eld',
#   'long_time',
#   'year',
#   'twelvemonth',
#   'class',
#   'age'],
#  'both': ['both'],
#  'among': [],
#  'least': ['least', 'to_the_lowest_degree'],
#  'wisdom': ['soundness',
#   'Wisdom_of_Solomon',
#   'sapience',
#   'wisdom',
#   'wiseness',
#   'Wisdom'],
#  'boldly': ['boldly'],
#  'other': ['early', 'other', 'former'],
#  'offering': ['pop_the_question',
#   'propose',
#   'offer',
#   'volunteer',
#   'extend',
#   'offer_up',
#   'proffer',
#   'declare_oneself',
#   'oblation',
#   'provide',
#   'bid',
#   'offering',
#   'put_up',
#   'tender'],
#  'nation': ['land',
#   'body_politic',
#   'Carry_Amelia_Moore_Nation',
#   'state',
#   'commonwealth',
#   'Carry_Nation',
#   'res_publica',
#   'nation',
#   'Nation',
#   'country'],
#  'destroy': ['destruct', 'destroy', 'put_down', 'ruin', 'demolish'],
#  'matters': ['matter',
#   'weigh',
#   'issue',
#   'count',
#   'affair',
#   'subject',
#   'thing',
#   'topic'],
#  'different': ['dissimilar', 'different', 'unlike'],
#  'services': ['avail',
#   'inspection_and_repair',
#   'Robert_William_Service',
#   'overhaul',
#   'religious_service',
#   'service',
#   'services',
#   'table_service',
#   'Service',
#   'serve',
#   'serving',
#   'military_service',
#   'divine_service',
#   'servicing',
#   'armed_service',
#   'service_of_process',
#   'help'],
#  'stage': ['microscope_stage',
#   'level',
#   'stagecoach',
#   'degree',
#   'present',
#   'leg',
#   'arrange',
#   'stage',
#   'represent',
#   'point',
#   'phase'],
#  'destroyed': ['destruct',
#   'destroy',
#   'ruined',
#   'put_down',
#   'ruin',
#   'destroyed',
#   'demolish'],
#  'orderly': ['neat', 'orderly', 'hospital_attendant'],
#  'These': [],
#  'honest': ['dependable',
#   'good',
#   'fair',
#   'honorable',
#   'reliable',
#   'honest',
#   'true'],
#  'must': ['moldiness', 'must', 'mustiness'],
#  'little': ['slight',
#   'short',
#   'petty',
#   'piddling',
#   'fiddling',
#   'small',
#   'little',
#   'niggling',
#   'trivial',
#   'piffling',
#   'lilliputian',
#   'picayune',
#   'minuscule',
#   'footling'],
#  'To': [],
#  'judgments': ['legal_opinion',
#   'judgment',
#   'sagacity',
#   'sound_judgment',
#   'judgement',
#   'opinion',
#   'discernment',
#   'assessment',
#   'judging',
#   'mind',
#   'sagaciousness',
#   'sound_judgement',
#   'judicial_decision',
#   'perspicacity'],
#  'Feelings': ['touch',
#   'feel',
#   'smell',
#   'sense',
#   'palpate',
#   'flavour',
#   'look',
#   'spirit',
#   'tone',
#   'tactile_sensation',
#   'notion',
#   'opinion',
#   'impression',
#   'touch_sensation',
#   'flavor',
#   'feelings',
#   'experience',
#   'feeling',
#   'intuitive_feeling',
#   'tactual_sensation',
#   'find',
#   'finger',
#   'belief'],
#  'can': ['can_buoy',
#   'john',
#   'bathroom',
#   'nates',
#   'force_out',
#   'rear',
#   'lavatory',
#   'stool',
#   'tin',
#   'commode',
#   'tush',
#   'derriere',
#   'rear_end',
#   'give_notice',
#   'tin_can',
#   'toilet',
#   'displace',
#   'prat',
#   'dismiss',
#   'can',
#   'potty',
#   'hindquarters',
#   'fire',
#   'stern',
#   'bum',
#   'give_the_axe',
#   'arse',
#   'send_away',
#   'give_the_sack',
#   'fundament',
#   'butt',
#   'put_up',
#   'hind_end',
#   'rump',
#   'canful',
#   'buns',
#   'crapper',
#   'fanny',
#   'ass',
#   'bottom',
#   'throne',
#   'seat',
#   'tail',
#   'posterior',
#   'tooshie',
#   'lav',
#   'sack',
#   'terminate',
#   'tail_end',
#   'pot',
#   'privy',
#   'backside',
#   'behind',
#   'keister',
#   'buttocks'],
#  'manner': ['style', 'way', 'personal_manner', 'fashion', 'mode', 'manner'],
#  'Simultaneously': ['at_the_same_time', 'simultaneously'],
#  'purpose': ['use',
#   'aim',
#   'propose',
#   'purpose',
#   'function',
#   'role',
#   'resolve',
#   'purport',
#   'intent',
#   'design',
#   'intention',
#   'determination'],
#  'afford': ['open', 'give', 'yield', 'afford'],
#  'its': ['information_technology', 'IT'],
#  'undertaken': ['take_on',
#   'contract',
#   'guarantee',
#   'undertake',
#   'take_in_charge',
#   'attempt',
#   'tackle',
#   'set_about'],
#  'alienated': ['disoriented',
#   'disaffect',
#   'estrange',
#   'alienate',
#   'alienated',
#   'alien',
#   'anomic',
#   'estranged'],
#  'long-term': ['long-run', 'semipermanent', 'long-term'],
#  'fashion': ['style', 'way', 'forge', 'fashion', 'mode', 'manner'],
#  'assure': ['ascertain',
#   'ensure',
#   'check',
#   'see_to_it',
#   'reassure',
#   'tell',
#   'control',
#   'guarantee',
#   'promise',
#   'insure',
#   'assure',
#   'secure',
#   'see'],
#  'duty': ['obligation', 'duty', 'responsibility', 'tariff'],
#  'Indian': ['Amerind',
#   'Amerindic',
#   'American_Indian',
#   'Red_Indian',
#   'American-Indian_language',
#   'Native_American',
#   'Indian',
#   'Amerindian_language'],
#  'communications': ['communications',
#   'communicating',
#   'communication',
#   'communication_theory'],
#  'into': [],
#  'has': ['hour_angle',
#   'have',
#   'accept',
#   'deliver',
#   'cause',
#   'ingest',
#   'throw',
#   'possess',
#   'take_in',
#   'induce',
#   'hold',
#   'own',
#   'bear',
#   'sustain',
#   'take',
#   'make',
#   'have_got',
#   'give',
#   'stimulate',
#   'experience',
#   'birth',
#   'feature',
#   'give_birth',
#   'receive',
#   'consume',
#   'let',
#   'HA',
#   'get',
#   'suffer'],
#  'exploit': ['overwork', 'exploit', 'tap', 'effort', 'work', 'feat'],
#  'genuine': ['real',
#   'actual',
#   'echt',
#   'unfeigned',
#   'genuine',
#   'literal',
#   'true'],
#  'depends': ['look', 'depend', 'bet', 'count', 'reckon', 'calculate'],
#  'prospects': ['prospect',
#   'view',
#   'chance',
#   'medical_prognosis',
#   'panorama',
#   'expectation',
#   'prognosis',
#   'vista',
#   'outlook',
#   'scene',
#   'candidate',
#   'aspect'],
#  'Program': ['program',
#   'course_of_study',
#   'broadcast',
#   'syllabus',
#   'plan',
#   'curriculum',
#   'political_program',
#   'political_platform',
#   'computer_programme',
#   'platform',
#   'programme',
#   'computer_program'],
#  'Capital': ['Das_Kapital',
#   'working_capital',
#   'Washington',
#   'cap',
#   'capital_letter',
#   'capital',
#   'Capital',
#   'chapiter',
#   'upper-case_letter',
#   'uppercase',
#   'majuscule',
#   'great'],
#  'Above': ['in_a_higher_place',
#   'above',
#   'supra',
#   'higher_up',
#   'to_a_higher_place'],
#  'attempt': ['set_about',
#   'endeavour',
#   'effort',
#   'assay',
#   'undertake',
#   'try',
#   'attack',
#   'attempt',
#   'seek',
#   'endeavor',
#   'essay'],
#  'perpetuate': ['perpetuate'],
#  'required': ['demand',
#   'ask',
#   'want',
#   'needful',
#   'requisite',
#   'compulsory',
#   'postulate',
#   'take',
#   'command',
#   'required',
#   'mandatory',
#   'need',
#   'needed',
#   'involve',
#   'expect',
#   'necessitate',
#   'call_for',
#   'require'],
#  'Progress': ['procession',
#   'move_on',
#   'pass_on',
#   'progression',
#   'build',
#   'advance',
#   'shape_up',
#   'go_on',
#   'march_on',
#   'forward_motion',
#   'progress',
#   'onward_motion',
#   'come_on',
#   'get_on',
#   'advancement',
#   'get_along',
#   'come_along',
#   'work_up',
#   'build_up'],
#  'develop': ['develop',
#   'uprise',
#   'prepare',
#   'germinate',
#   'recrudesce',
#   'make_grow',
#   'explicate',
#   'train',
#   'rise',
#   'break',
#   'evolve',
#   'modernise',
#   'arise',
#   'originate',
#   'acquire',
#   'modernize',
#   'formulate',
#   'grow',
#   'educate',
#   'get',
#   'produce',
#   'spring_up',
#   'build_up'],
#  'assist': ['assist',
#   'wait_on',
#   'attend_to',
#   'serve',
#   'aid',
#   'assistance',
#   'attend',
#   'help'],
#  'smaller': ['pocket-sized',
#   'smaller',
#   'small-scale',
#   'belittled',
#   'pocket-size',
#   'diminished',
#   'low',
#   'lowly',
#   'small',
#   'little',
#   'minor',
#   'littler',
#   'modest',
#   'minuscule',
#   'humble'],
#  'program': ['program',
#   'course_of_study',
#   'broadcast',
#   'syllabus',
#   'plan',
#   'curriculum',
#   'political_program',
#   'political_platform',
#   'computer_programme',
#   'platform',
#   'programme',
#   'computer_program'],
#  'emphasis': ['vehemence', 'accent', 'emphasis', 'stress'],
#  'communities': ['residential_area',
#   'biotic_community',
#   'community',
#   'community_of_interests',
#   'residential_district'],
#  'their': [],
#  'introduced': ['enter',
#   'introduce',
#   'bring_out',
#   'precede',
#   'preface',
#   'bring_in',
#   'premise',
#   'acquaint',
#   'stick_in',
#   'inclose',
#   'insert',
#   'innovate',
#   'enclose',
#   'inaugurate',
#   'put_in',
#   'present',
#   'usher_in',
#   'infix'],
#  'considerable': ['considerable'],
#  'nationalism': ['patriotism', 'nationalism'],
#  'inhibitions': ['prohibition', 'inhibition', 'forbiddance', 'suppression'],
#  'communicate': ['intercommunicate',
#   'transmit',
#   'commune',
#   'pass',
#   'pass_on',
#   'convey',
#   'communicate',
#   'put_across',
#   'pass_along'],
#  'claims': ['exact',
#   'title',
#   'take',
#   'lay_claim',
#   'arrogate',
#   'claim',
#   'call'],
#  'growth': ['maturation',
#   'ontogenesis',
#   'growing',
#   'outgrowth',
#   'development',
#   'ontogeny',
#   'increase',
#   'increment',
#   'growth',
#   'emergence'],
#  'society': ['society',
#   'high_society',
#   'company',
#   'companionship',
#   'social_club',
#   'gild',
#   'order',
#   'guild',
#   'lodge',
#   'fellowship',
#   'beau_monde',
#   'smart_set',
#   'bon_ton',
#   'club'],
#  'failure': ['failure',
#   'nonstarter',
#   'unsuccessful_person',
#   'loser',
#   'bankruptcy'],
#  'taken': ['lead',
#   'take_on',
#   'pick_out',
#   'study',
#   'have',
#   'accept',
#   'get_hold_of',
#   'learn',
#   'subscribe',
#   'ingest',
#   'drive',
#   'hire',
#   'occupy',
#   'train',
#   'conduct',
#   'take_aim',
#   'admit',
#   'lease',
#   'aim',
#   'taken',
#   'take_in',
#   'contract',
#   'film',
#   'carry',
#   'subscribe_to',
#   'need',
#   'claim',
#   'hold',
#   'assume',
#   'necessitate',
#   'charter',
#   'strike',
#   'rent',
#   'require',
#   'direct',
#   'select',
#   'demand',
#   'guide',
#   'exact',
#   'bring',
#   'take_up',
#   'take',
#   'postulate',
#   'make',
#   'convey',
#   'acquire',
#   'engage',
#   'involve',
#   'consider',
#   'deal',
#   'interpreted',
#   'choose',
#   'use_up',
#   'fill',
#   'call_for',
#   'shoot',
#   'take_away',
#   'ask',
#   'remove',
#   'read',
#   'contain',
#   'adopt',
#   'look_at',
#   'consume',
#   'submit',
#   'withdraw',
#   'get',
#   'pack'],
#  'escaped': ['scarper',
#   'take_to_the_woods',
#   'on_the_loose',
#   'bunk',
#   'escape',
#   'miss',
#   'escaped',
#   'scat',
#   'run',
#   'run_away',
#   'fly_the_coop',
#   'elude',
#   'hightail_it',
#   'break_away',
#   'loose',
#   'get_by',
#   'lam',
#   'get_out',
#   'break_loose',
#   'at_large',
#   'get_away',
#   'head_for_the_hills',
#   'turn_tail',
#   'get_off'],
#  'obstacles': ['obstruction', 'obstacle'],
#  'adventures': ['risky_venture',
#   'adventure',
#   'risk',
#   'chance',
#   'hazard',
#   'dangerous_undertaking',
#   'run_a_risk',
#   'take_a_chance',
#   'take_chances',
#   'jeopardize',
#   'stake',
#   'escapade',
#   'gamble',
#   'venture'],
#  'fulfillment': ['fulfilment', 'fulfillment'],
#  'forward-moving': ['forward', 'advancing', 'forward-moving'],
#  'reasonably': ['sanely',
#   'middling',
#   'pretty',
#   'reasonably',
#   'jolly',
#   'somewhat',
#   'fairly',
#   'passably',
#   'moderately',
#   'sensibly'],
#  'covering': ['brood',
#   'extend',
#   'plow',
#   'address',
#   'report',
#   'overlay',
#   'continue',
#   'breed',
#   'encompass',
#   'cover',
#   'hide',
#   'masking',
#   'cut_across',
#   'embrace',
#   'incubate',
#   'get_over',
#   'wrap_up',
#   'covering',
#   'enshroud',
#   'screening',
#   'traverse',
#   'insure',
#   'get_across',
#   'compensate',
#   'handle',
#   'comprehend',
#   'treat',
#   'application',
#   'track',
#   'natural_covering',
#   'underwrite',
#   'cover_up',
#   'deal',
#   'overcompensate',
#   'cross',
#   'hatch',
#   'spread_over',
#   'coating',
#   'cut_through',
#   'shroud',
#   'pass_over'],
#  'built': ['reinforced',
#   'construct',
#   'progress',
#   'built',
#   'make',
#   'establish',
#   'ramp_up',
#   'build',
#   'work_up',
#   'build_up'],
#  'need': ['demand',
#   'ask',
#   'want',
#   'penury',
#   'postulate',
#   'take',
#   'pauperism',
#   'pauperization',
#   'indigence',
#   'need',
#   'involve',
#   'require',
#   'necessitate',
#   'call_for',
#   'motive',
#   'motivation'],
#  'Actively': ['actively'],
#  'people': ['citizenry',
#   'the_great_unwashed',
#   'masses',
#   'hoi_polloi',
#   'people',
#   'mass',
#   'multitude'],
#  'tackle': ['rigging',
#   'fishing_gear',
#   'rig',
#   'take_on',
#   'undertake',
#   'harness',
#   'fishing_tackle',
#   'tackle',
#   'fishing_rig'],
#  'those': [],
#  'second': ['secondly',
#   'secondment',
#   '2d',
#   'mo',
#   'indorsement',
#   'irregular',
#   'moment',
#   'sec',
#   'second_gear',
#   'indorse',
#   '2nd',
#   'second',
#   'bit',
#   'instant',
#   'minute',
#   'endorsement',
#   'second_base',
#   's',
#   'arcsecond',
#   'endorse',
#   'back'],
#  'potential': ['potential',
#   'possible',
#   'potential_difference',
#   'likely',
#   'electric_potential',
#   'potential_drop',
#   'potentiality',
#   'potency',
#   'voltage'],
#  'live': ['springy',
#   'exist',
#   'resilient',
#   'lively',
#   'hold_up',
#   'be',
#   'populate',
#   'last',
#   'survive',
#   'hot',
#   'hold_out',
#   'dwell',
#   'endure',
#   'subsist',
#   'live',
#   'go',
#   'unrecorded',
#   'experience',
#   'know',
#   'inhabit',
#   'bouncy',
#   'live_on',
#   'alive'],
#  'groups': ['mathematical_group',
#   'group',
#   'chemical_group',
#   'radical',
#   'aggroup',
#   'grouping'],
#  'unpleasant': ['unpleasant'],
#  ',': [],
#  'big': ['heavy',
#   'with_child',
#   'braggy',
#   'vauntingly',
#   'fully_grown',
#   'boastfully',
#   'adult',
#   'prominent',
#   'self-aggrandising',
#   'magnanimous',
#   'braggart',
#   'full-grown',
#   'large',
#   'handsome',
#   'bighearted',
#   'freehanded',
#   'grownup',
#   'openhanded',
#   'bounteous',
#   'boastful',
#   'cock-a-hoop',
#   'bad',
#   'enceinte',
#   'liberal',
#   'big',
#   'grown',
#   'giving',
#   'bragging',
#   'great',
#   'gravid',
#   'swelled',
#   'crowing',
#   'self-aggrandizing',
#   'vainglorious',
#   'bountiful',
#   'expectant'],
#  'isolated': ['apart',
#   'isolate',
#   'sequestrate',
#   'keep_apart',
#   'stray',
#   'quarantined',
#   'stranded',
#   'isolated',
#   'obscure',
#   'insulate',
#   'detached',
#   'disjunct',
#   'marooned',
#   'set_apart',
#   'sequester',
#   'set-apart',
#   'separated'],
#  'old': ['one-time',
#   'sure-enough',
#   'former',
#   'older',
#   'sometime',
#   'previous',
#   'erstwhile',
#   'honest-to-goodness',
#   'old',
#   'Old',
#   'honest-to-god',
#   'quondam',
#   'onetime'],
#  'are': ['ar',
#   'comprise',
#   'live',
#   'constitute',
#   'exist',
#   'be',
#   'represent',
#   'personify',
#   'are',
#   'follow',
#   'make_up',
#   'cost',
#   'embody',
#   'equal'],
#  'creatively': ['creatively'],
#  'although': [],
#  'far': ['Interahamwe',
#   'FAR',
#   'far',
#   'Army_for_the_Liberation_of_Rwanda',
#   'Former_Armed_Forces',
#   'ALIR'],
#  'constantly': ['always',
#   'forever',
#   'constantly',
#   'incessantly',
#   'invariably',
#   'perpetually'],
#  'certain': ['sure', 'certain', 'sealed'],
#  'wide': ['across-the-board',
#   'full',
#   'wide-eyed',
#   'astray',
#   'blanket',
#   'wide',
#   'encompassing',
#   'panoptic',
#   'all-embracing',
#   'all-encompassing',
#   'spacious',
#   'wide-cut',
#   'wide_of_the_mark',
#   'extensive',
#   'widely',
#   'all-inclusive',
#   'broad'],
#  'governments': ['regime',
#   'government_activity',
#   'governance',
#   'administration',
#   'governing',
#   'politics',
#   'authorities',
#   'political_science',
#   'government'],
#  'pressing': ['press',
#   'weight-lift',
#   'press_out',
#   'agitate',
#   'constrict',
#   'iron_out',
#   'exhort',
#   'weightlift',
#   'contract',
#   'pressure',
#   'urge_on',
#   'weigh',
#   'compress',
#   'crusade',
#   'iron',
#   'beseech',
#   'adjure',
#   'push',
#   'campaign',
#   'compact',
#   'squeeze',
#   'fight',
#   'urgent',
#   'pressing',
#   'bid',
#   'conjure',
#   'urge',
#   'entreat'],
#  'basically': ['fundamentally', 'essentially', 'basically'],
#  'employed': ['use',
#   'apply',
#   'utilize',
#   'utilise',
#   'engage',
#   'employed',
#   'employ',
#   'hire'],
#  'resources': ['resourcefulness', 'resource', 'imagination'],
#  'pace': ['tempo',
#   'stride',
#   'step',
#   'tread',
#   'yard',
#   'rate',
#   'gait',
#   'pace',
#   'footstep'],
#  'wait': ['hold_off',
#   'look',
#   'hold_back',
#   'await',
#   'wait',
#   'time_lag',
#   'delay',
#   'postponement',
#   'hold',
#   'waiting',
#   'waitress',
#   'expect'],
#  'feel': ['experience',
#   'flavour',
#   'look',
#   'spirit',
#   'flavor',
#   'feeling',
#   'feel',
#   'tone',
#   'find',
#   'smell',
#   'sense',
#   'finger',
#   'palpate',
#   'tactile_property'],
#  'uncertainty': ['dubiety',
#   'incertitude',
#   'uncertainty',
#   'doubt',
#   'doubtfulness',
#   'dubiousness',
#   'precariousness',
#   'uncertainness'],
#  'having': ['have',
#   'accept',
#   'deliver',
#   'cause',
#   'ingest',
#   'throw',
#   'possess',
#   'take_in',
#   'induce',
#   'hold',
#   'own',
#   'bear',
#   'sustain',
#   'take',
#   'make',
#   'have_got',
#   'give',
#   'stimulate',
#   'experience',
#   'birth',
#   'feature',
#   'give_birth',
#   'receive',
#   'consume',
#   'let',
#   'get',
#   'suffer'],
#  'tentative': ['provisional',
#   'probationary',
#   'tentative',
#   'provisionary',
#   'doubtful'],
#  'management': ['direction', 'management'],
#  'several': ['various', 'respective', 'several'],
#  'thus': ['olibanum',
#   'gum_olibanum',
#   'therefore',
#   'frankincense',
#   'thence',
#   'thusly',
#   'thus',
#   'so',
#   'hence'],
#  'merely': ['but', 'just', 'simply', 'merely', 'only'],
#  'where': [],
#  'based': ['found', 'ground', 'free-base', 'establish', 'base', 'based'],
#  'labor': ['Labor',
#   'grind',
#   'dig',
#   'proletariat',
#   'drive',
#   'toil',
#   'labor',
#   'Labour',
#   'drudge',
#   'travail',
#   'trade_union_movement',
#   'task',
#   'fag',
#   'labour',
#   'Labor_Department',
#   'confinement',
#   'push',
#   'moil',
#   'tug',
#   'British_Labour_Party',
#   'Labour_Party',
#   'lying-in',
#   'parturiency',
#   'DoL',
#   'labor_movement',
#   'working_class',
#   'childbed',
#   'Department_of_Labor',
#   'undertaking',
#   'project'],
#  'administrative': ['administrative'],
#  'from': [],
#  'begun': ['begin',
#   'start',
#   'get_down',
#   'commence',
#   'lead_off',
#   'start_out',
#   'get',
#   'set_out',
#   'set_about'],
#  'making': ['wee',
#   'constitute',
#   'prepare',
#   'pee-pee',
#   'have',
#   'get_to',
#   'attain',
#   'cook',
#   'spend_a_penny',
#   'cause',
#   'create',
#   'shit',
#   'name',
#   'build',
#   'throw',
#   'fix',
#   'score',
#   'make_up',
#   'stool',
#   'piddle',
#   'arrive_at',
#   'realise',
#   'puddle',
#   'wee-wee',
#   'pass_water',
#   'construct',
#   'ready',
#   'take_in',
#   'making',
#   'defecate',
#   'urinate',
#   'seduce',
#   'induce',
#   'nominate',
#   'hold',
#   'ca-ca',
#   'lay_down',
#   'draw',
#   'do',
#   'bring_in',
#   'take',
#   'take_a_shit',
#   'make',
#   'take_a_crap',
#   'give',
#   'stimulate',
#   'realize',
#   'pretend',
#   'form',
#   'make_believe',
#   'micturate',
#   'crap',
#   'earn',
#   'reach',
#   'pull_in',
#   'progress_to',
#   'relieve_oneself',
#   'clear',
#   'pee',
#   'gain',
#   'hit',
#   'take_a_leak',
#   'fashioning',
#   'devising',
#   'work',
#   'establish',
#   'get',
#   'produce',
#   'qualification',
#   'piss',
#   'make_water'],
#  'accordance': ['accord', 'accordance', 'conformity', 'accordance_of_rights'],
#  'relatively': ['relatively', 'comparatively'],
#  'reference': ['cite',
#   'denotation',
#   'address',
#   'credit',
#   'character_reference',
#   'reference',
#   'reference_point',
#   'extension',
#   'reference_book',
#   'reference_work',
#   'book_of_facts',
#   'consultation',
#   'source',
#   'character',
#   'citation',
#   'quotation',
#   'mention',
#   'point_of_reference',
#   'computer_address',
#   'acknowledgment'],
#  'country': ['land',
#   'body_politic',
#   'area',
#   'rural_area',
#   'state',
#   'commonwealth',
#   'res_publica',
#   'nation',
#   'country'],
#  'call': ['phone',
#   'visit',
#   'telephone_call',
#   'cry',
#   'address',
#   'call_option',
#   'name',
#   'anticipate',
#   'margin_call',
#   'outcry',
#   'telephone',
#   'birdsong',
#   'hollo',
#   'Call',
#   'shout',
#   'claim',
#   'squall',
#   'call',
#   'send_for',
#   'prognosticate',
#   'holler',
#   'birdcall',
#   'scream',
#   'predict',
#   'song',
#   'forebode',
#   'phone_call',
#   'call_in',
#   'ring',
#   'call_off',
#   'yell',
#   'call_up',
#   'shout_out',
#   'foretell',
#   'promise',
#   'bid',
#   'vociferation'],
#  'mobilize': ['mobilise',
#   'summon',
#   'call_up',
#   'rally',
#   'marshal',
#   'circulate',
#   'mobilize'],
#  'account': ['bill',
#   'write_up',
#   'account',
#   'answer_for',
#   'accounting',
#   'story',
#   'report',
#   'calculate',
#   'history',
#   'account_statement',
#   'business_relationship',
#   'score',
#   'invoice',
#   'explanation',
#   'news_report',
#   'chronicle',
#   'describe'],
#  'new': ['newfangled',
#   'Modern',
#   'unexampled',
#   'freshly',
#   'new',
#   'newly',
#   'fresh',
#   'novel',
#   'New',
#   'raw',
#   'young'],
#  'programming': ['scheduling',
#   'program',
#   'computer_programing',
#   'programming',
#   'programme',
#   'programing',
#   'computer_programming'],
#  'still': ['tranquillise',
#   'however',
#   'motionless',
#   'lull',
#   'withal',
#   'shut_up',
#   'allay',
#   'noneffervescent',
#   'smooth',
#   'quieten',
#   'hush_up',
#   'static',
#   'calm',
#   'silent',
#   'ease',
#   'distillery',
#   'notwithstanding',
#   'unruffled',
#   'tranquilize',
#   'soundless',
#   'still',
#   'inactive',
#   'even_so',
#   'tranquil',
#   'tranquillize',
#   'yet',
#   'relieve',
#   'quiet',
#   'nevertheless',
#   'silence',
#   'placid',
#   'all_the_same',
#   'stock-still',
#   'stillness',
#   'even',
#   'hush',
#   'nonetheless',
#   'calm_down'],
#  'itself': [],
#  'There': ['at_that_place',
#   'there',
#   'in_that_location',
#   'thither',
#   'on_that_point',
#   'in_that_respect'],
#  'ruling': ['rein',
#   'predominate',
#   'decree',
#   'prevail',
#   'opinion',
#   'ruling',
#   'find',
#   'dominate',
#   'harness',
#   'reign',
#   'rule',
#   'govern',
#   'regnant',
#   'reigning'],
#  'objectives': ['aim',
#   'objective',
#   'object_lens',
#   'objective_lens',
#   'target',
#   'object',
#   'object_glass'],
#  'already': ['already'],
#  'up': ['astir', 'upward', 'upwardly', 'improving', 'up', 'upwards'],
#  'without': [],
#  'rapidly': ['speedily', 'quickly', 'apace', 'rapidly', 'chop-chop'],
#  'dual': ['threefold',
#   'treble',
#   'two-fold',
#   'three-fold',
#   'duple',
#   'twofold',
#   'double',
#   'dual'],
#  'advisor': ['adviser', 'consultant', 'advisor'],
#  'equate': ['equate',
#   'liken',
#   'correspond',
#   'compare',
#   'match',
#   'equalize',
#   'equalise',
#   'equal'],
#  'drawn': ['imbibe',
#   'tie',
#   'haggard',
#   'draw_in',
#   'careworn',
#   'cast',
#   'disembowel',
#   'soak_up',
#   'take_in',
#   'trace',
#   'pull',
#   'run',
#   'force',
#   'quarter',
#   'delineate',
#   'absorb',
#   'draw',
#   'puff',
#   'depict',
#   'sop_up',
#   'guide',
#   'take_up',
#   'drag',
#   'pass',
#   'pull_back',
#   'eviscerate',
#   'make',
#   'string',
#   'get_out',
#   'pull_in',
#   'describe',
#   'raddled',
#   'suck',
#   'drawn',
#   'draw_off',
#   'worn',
#   'suck_up',
#   'draw_and_quarter',
#   'attract',
#   'reap',
#   'withdraw',
#   'get',
#   'thread',
#   'line',
#   'take_out',
#   'pull_out'],
#  'solved': ['clear',
#   'figure_out',
#   'lick',
#   'resolve',
#   'solve',
#   'solved',
#   'work',
#   'puzzle_out',
#   'work_out',
#   'resolved'],
#  'we': [],
#  'policy': ['insurance', 'insurance_policy', 'policy'],
#  'segment': ['segment', 'section'],
#  'reform': ['regenerate',
#   'straighten_out',
#   'rectify',
#   'reclaim',
#   'reform',
#   'see_the_light'],
#  'third': ['tertiary',
#   'thirdly',
#   'third',
#   'tierce',
#   '3rd',
#   'third_base',
#   'third_gear',
#   'one-third'],
#  'display': ['exhibit',
#   'presentation',
#   'expose',
#   'showing',
#   'video_display',
#   'show',
#   'display'],
#  'place': ['property',
#   'office',
#   'spot',
#   'piazza',
#   'lieu',
#   'come_out',
#   'order',
#   'pose',
#   'topographic_point',
#   'situation',
#   'position',
#   'aim',
#   'shoes',
#   'billet',
#   'send',
#   'put',
#   'grade',
#   'space',
#   'direct',
#   'berth',
#   'station',
#   'lay',
#   'localise',
#   'range',
#   'rate',
#   'commit',
#   'identify',
#   'home',
#   'invest',
#   'set',
#   'blank_space',
#   'come_in',
#   'stead',
#   'seat',
#   'post',
#   'locate',
#   'site',
#   'target',
#   'rank',
#   'localize',
#   'plaza',
#   'place',
#   'point'],
#  'Thus': ['olibanum',
#   'gum_olibanum',
#   'therefore',
#   'frankincense',
#   'thence',
#   'thusly',
#   'thus',
#   'so',
#   'hence'],
#  'of': [],
#  'each': ['each', 'to_each_one', 'from_each_one', 'for_each_one', 'apiece'],
#  'relations': ['sexual_congress',
#   'relations',
#   'dealings',
#   'sex_act',
#   'intercourse',
#   'recounting',
#   'congress',
#   'relative',
#   'carnal_knowledge',
#   'copulation',
#   'sexual_intercourse',
#   'coitus',
#   'telling',
#   'coition',
#   'relation',
#   'sexual_relation',
#   'relation_back'],
#  'politically': ['politically'],
#  'about': ['just_about',
#   'about',
#   'more_or_less',
#   'most',
#   'astir',
#   'approximately',
#   'near',
#   'nigh',
#   'virtually',
#   'well-nigh',
#   'or_so',
#   'around',
#   'nearly',
#   'roughly',
#   'close_to',
#   'almost',
#   'some'],
#  'This': [],
#  'have': ['have',
#   'accept',
#   'deliver',
#   'cause',
#   'ingest',
#   'throw',
#   'wealthy_person',
#   'possess',
#   'take_in',
#   'induce',
#   'hold',
#   'own',
#   'bear',
#   'sustain',
#   'rich_person',
#   'take',
#   'make',
#   'have_got',
#   'give',
#   'stimulate',
#   'experience',
#   'birth',
#   'feature',
#   'give_birth',
#   'receive',
#   'consume',
#   'let',
#   'get',
#   'suffer'],
#  'Iraq': ['Iraq', 'Al-Iraq', 'Republic_of_Iraq', 'Irak'],
#  'development': ['maturation',
#   'ontogenesis',
#   'growing',
#   'development',
#   'ontogeny',
#   'developing',
#   'exploitation',
#   'evolution',
#   'growth'],
#  'farm': ['grow', 'produce', 'farm', 'raise'],
#  'exchange': ['commutation',
#   'switch',
#   'change',
#   'replace',
#   'central',
#   'switch_over',
#   'exchange',
#   'convert',
#   'commute',
#   'rally',
#   'substitution',
#   'interchange',
#   'substitute',
#   'telephone_exchange'],
#  'instead': ['alternatively', 'instead', 'or_else', 'rather'],
#  'sense': ['sentience',
#   'gumption',
#   'common_sense',
#   'good_sense',
#   'feel',
#   'horse_sense',
#   'smell_out',
#   'sensory_faculty',
#   'sense',
#   'smell',
#   'mother_wit',
#   'sensation',
#   'signified',
#   'sentiency'],
#  'mobilized': ['mobilise',
#   'summon',
#   'call_up',
#   'rally',
#   'marshal',
#   'circulate',
#   'mobilize'],
#  'exceed': ['go_past',
#   'top',
#   'outmatch',
#   'surpass',
#   'outgo',
#   'surmount',
#   'outperform',
#   'pass',
#   'outstrip',
#   'overstep',
#   'exceed',
#   'transcend',
#   'outdo'],
#  'early': ['early',
#   'too_soon',
#   'former',
#   'ahead_of_time',
#   'betimes',
#   'other',
#   'early_on'],
#  'famed': ['renowned',
#   'famed',
#   'noted',
#   'notable',
#   'far-famed',
#   'famous',
#   'illustrious',
#   'celebrated'],
#  'and': [],
#  'private': ['individual',
#   'private',
#   'common_soldier',
#   'buck_private',
#   'secret'],
#  'incentives': ['bonus', 'motivator', 'incentive', 'inducement'],
#  'permit': ['permission',
#   'permit',
#   'countenance',
#   'let',
#   'license',
#   'Trachinotus_falcatus',
#   'licence',
#   'tolerate',
#   'allow'],
#  'skillfully': ['skillfully', 'skilfully'],
#  'central': ['central',
#   'fundamental',
#   'exchange',
#   'primal',
#   'cardinal',
#   'key',
#   'telephone_exchange'],
#  'inflexible': ['unbending',
#   'rigid',
#   'inflexible',
#   'sturdy',
#   'uncompromising'],
#  'any': ['whatsoever', 'any', 'whatever'],
#  'The': [],
#  'forward': ['frontward',
#   'frontwards',
#   'forward-moving',
#   'onward',
#   'send_on',
#   'forth',
#   'advancing',
#   'forrad',
#   'ahead',
#   'forrard',
#   'forrader',
#   'fore',
#   'forward',
#   'forwards',
#   'onwards'],
#  'acceptance': ['credence',
#   'toleration',
#   'acceptation',
#   'adoption',
#   'sufferance',
#   'espousal',
#   'acceptance',
#   "banker's_acceptance"],
#  'colonial': ['colonial', 'compound'],
#  'rely': ['trust', 'rely', 'swear', 'bank'],
#  'impeded': ['impede',
#   'impeded',
#   'obturate',
#   'occlude',
#   'obstruct',
#   'close_up',
#   'jam',
#   'block',
#   'hinder'],
#  'do': ['answer',
#   'coiffure',
#   'cause',
#   'serve',
#   'dress',
#   'exercise',
#   'act',
#   'coiffe',
#   'doh',
#   'ut',
#   'bash',
#   'Doctor_of_Osteopathy',
#   'perform',
#   'do',
#   'suffice',
#   'fare',
#   'DO',
#   'practice',
#   'make',
#   'set',
#   'make_out',
#   'come',
#   'brawl',
#   'arrange',
#   'coif',
#   'manage',
#   'get_along',
#   'practise',
#   'behave',
#   'execute'],
#  'confusion': ['confusedness',
#   'confusion',
#   'discombobulation',
#   'mental_confusion',
#   'disarray',
#   'muddiness',
#   'mix-up'],
#  'begin': ['Menachem_Begin',
#   'begin',
#   'start',
#   'get_down',
#   'Begin',
#   'commence',
#   'lead_off',
#   'get',
#   'start_out',
#   'set_out',
#   'set_about'],
#  'being': ['existence',
#   'comprise',
#   'beingness',
#   'live',
#   'constitute',
#   'exist',
#   'being',
#   'organism',
#   'be',
#   'represent',
#   'personify',
#   'follow',
#   'make_up',
#   'cost',
#   'embody',
#   'equal'],
#  'upper-level': ['high-level', 'high-ranking', 'upper-level'],
#  'social': ['sociable', 'mixer', 'societal', 'social'],
#  'underline': ['emphasize', 'emphasise', 'underscore', 'underline'],
#  'related': ['touch',
#   'bear_on',
#   'colligate',
#   'link',
#   'concern',
#   'interrelate',
#   'related_to',
#   'touch_on',
#   'relate',
#   'connect',
#   'related',
#   'refer',
#   'have-to_doe_with',
#   'link_up',
#   'pertain',
#   'come_to',
#   'associate',
#   'tie_in'],
#  'consequence': ['event',
#   'import',
#   'effect',
#   'issue',
#   'outcome',
#   'upshot',
#   'consequence',
#   'result',
#   'moment',
#   'aftermath'],
#  'diversions': ['deviation',
#   'deflection',
#   'deflexion',
#   'diversion',
#   'recreation',
#   'digression',
#   'divagation',
#   'diversionary_attack'],
#  'needs': ['of_necessity',
#   'inevitably',
#   'motive',
#   'penury',
#   'need',
#   'necessitate',
#   'require',
#   'demand',
#   'want',
#   'postulate',
#   'take',
#   'involve',
#   'needs',
#   'call_for',
#   'ask',
#   'pauperism',
#   'pauperization',
#   'indigence',
#   'necessarily',
#   'motivation'],
#  'relation': ['sexual_congress',
#   'sex_act',
#   'intercourse',
#   'recounting',
#   'congress',
#   'relative',
#   'carnal_knowledge',
#   'copulation',
#   'sexual_intercourse',
#   'coitus',
#   'telling',
#   'coition',
#   'relation',
#   'sexual_relation',
#   'relation_back'],
#  'Iran': ['Islamic_Republic_of_Iran', 'Iran', 'Persia'],
#  'agenda': ['schedule', 'docket', 'agendum', 'order_of_business', 'agenda'],
#  'there': ['at_that_place',
#   'there',
#   'in_that_location',
#   'thither',
#   'on_that_point',
#   'in_that_respect'],
#  'believing': ['believing',
#   'believe',
#   'trust',
#   'consider',
#   'think',
#   'conceive'],
#  'status': ['condition', 'position', 'status'],
#  'major': ['John_Major', 'major', 'John_R._Major', 'John_Roy_Major', 'Major'],
#  'They': [],
#  'actions': ['sue',
#   'fulfill',
#   'carry_out',
#   'natural_process',
#   'carry_through',
#   'fulfil',
#   'action_at_law',
#   'action',
#   'process',
#   'action_mechanism',
#   'activity',
#   'litigate',
#   'legal_action',
#   'military_action',
#   'activeness',
#   'accomplish',
#   'natural_action',
#   'execute'],
#  'a': ['angstrom_unit',
#   'axerophthol',
#   'adenine',
#   'antiophthalmic_factor',
#   'A',
#   'amp',
#   'a',
#   'vitamin_A',
#   'angstrom',
#   'type_A',
#   'group_A',
#   'ampere',
#   'deoxyadenosine_monophosphate'],
#  'gradually': ['gradually', 'bit_by_bit', 'step_by_step'],
#  'standards': ['measure',
#   'standard',
#   'touchstone',
#   'criterion',
#   'banner',
#   'monetary_standard'],
#  '.': [],
#  'trained': ['develop',
#   'cultivate',
#   'school',
#   'prepare',
#   'train',
#   'take_aim',
#   'aim',
#   'discipline',
#   'trail',
#   'civilise',
#   'groom',
#   'direct',
#   'condition',
#   'coach',
#   'take',
#   'rail',
#   'civilize',
#   'check',
#   'educate',
#   'trained'],
# ...
#  'follows': ['watch_over',
#   'conform_to',
#   'stick_to',
#   'surveil',
#   'be',
#   'take_after',
#   'keep_an_eye_on',
#   'espouse',
#   'observe',
#   'play_along',
#   'keep_abreast',
#   'trace',
#   'succeed',
#   'accompany',
#   'come_after',
#   'abide_by',
#   'stick_with',
#   'pursue',
#   'follow',
#   'survey',
#   'postdate',
#   'fall_out',
#   'watch',
#   'comply',
#   'adopt',
#   'come',
#   'travel_along',
#   'keep_up'],
#  'aid': ['care',
#   'assist',
#   'financial_aid',
#   'tending',
#   'aid',
#   'assistance',
#   'economic_aid',
#   'attention',
#   'help'],
#  'ambitions': ['aspiration', 'ambitiousness', 'ambition', 'dream'],
#  'only': ['only_if',
#   'solely',
#   'but',
#   'just',
#   'entirely',
#   'solitary',
#   'alone',
#   'exclusively',
#   'only_when',
#   'simply',
#   'lone',
#   'merely',
#   'sole',
#   'only',
#   'lonesome'],
#  'system': ['organization',
#   'arrangement',
#   'system_of_rules',
#   'organisation',
#   'scheme',
#   'system'],
#  'rulers': ['rule', 'swayer', 'ruler'],
#  'sorts': ['classify',
#   'separate',
#   'sieve',
#   'screen',
#   'kind',
#   'screen_out',
#   'sorting',
#   'assort',
#   'form',
#   'sort',
#   'sort_out',
#   'class',
#   'variety'],
#  'land': ['body_politic',
#   'farming',
#   'put_down',
#   'soil',
#   'realm',
#   'estate',
#   'land',
#   'ground',
#   'Din_Land',
#   'set_down',
#   'res_publica',
#   'terra_firma',
#   'domain',
#   'country',
#   'Edwin_Herbert_Land',
#   'earth',
#   'shoot_down',
#   'bring',
#   'dry_land',
#   'state',
#   'bring_down',
#   'down',
#   'shore',
#   'landed_estate',
#   'demesne',
#   'solid_ground',
#   'commonwealth',
#   'kingdom',
#   'set_ashore',
#   'acres',
#   'Land',
#   'nation'],
#  'generally': ['more_often_than_not',
#   'generally',
#   'mostly',
#   'in_general',
#   'in_the_main',
#   'by_and_large',
#   'loosely',
#   'broadly_speaking',
#   'broadly'],
#  'number': ['routine',
#   'amount',
#   'total',
#   'turn',
#   'act',
#   'numerate',
#   'numeral',
#   'number',
#   'list',
#   'identification_number',
#   'count',
#   'bit',
#   'add_up',
#   'telephone_number',
#   'keep_down',
#   'figure',
#   'enumerate',
#   'issue',
#   'come',
#   'phone_number'],
#  'become': ['go', 'become', 'get', 'suit', 'turn'],
#  'whose': [],
#  'men': ['human_race',
#   'adult_male',
#   'serviceman',
#   'gentleman',
#   'manpower',
#   'valet',
#   'world',
#   "gentleman's_gentleman",
#   'hands',
#   'valet_de_chambre',
#   'men',
#   'humankind',
#   'homo',
#   'Isle_of_Man',
#   'work_force',
#   'humanity',
#   'humans',
#   'military_personnel',
#   'human_beings',
#   'Man',
#   'military_man',
#   'workforce',
#   'piece',
#   'human',
#   'man',
#   'human_being',
#   'mankind'],
#  'structures': ['anatomical_structure',
#   'bodily_structure',
#   'complex_body_part',
#   'structure',
#   'construction',
#   'social_organisation',
#   'social_organization',
#   'social_system',
#   'social_structure',
#   'body_structure'],
#  'imposed': ['inflict',
#   'visit',
#   'enforce',
#   'imposed',
#   'levy',
#   'impose',
#   'bring_down'],
#  'count': ['look',
#   'numeration',
#   'matter',
#   'enumerate',
#   'counting',
#   'reckoning',
#   'tally',
#   'number',
#   'depend',
#   'bet',
#   'calculate',
#   'count',
#   'consider',
#   'enumeration',
#   'reckon',
#   'numerate',
#   'weigh'],
#  'demonstrated': ['attest',
#   'exhibit',
#   'demo',
#   'evidence',
#   'show',
#   'establish',
#   'demonstrate',
#   'prove',
#   'demonstrated',
#   'shew',
#   'certify',
#   'present',
#   'manifest',
#   'march'],
#  'comparative': ['comparative', 'relative', 'comparative_degree'],
#  'varying': ['variegate',
#   'depart',
#   'change',
#   'alter',
#   'variable',
#   'diverge',
#   'motley',
#   'vary',
#   'varying',
#   'deviate'],
#  'claiming': ['exact', 'take', 'arrogate', 'lay_claim', 'claim'],
#  'go': ['move',
#   'blend_in',
#   'lead',
#   'die',
#   'start',
#   'extend',
#   'disco_biscuit',
#   'hold_up',
#   'XTC',
#   "cash_in_one's_chips",
#   'choke',
#   'turn',
#   'give-up_the_ghost',
#   'last',
#   'pop_off',
#   'survive',
#   'fling',
#   'proceed',
#   'hold_out',
#   'give_way',
#   'go_bad',
#   'belong',
#   'kick_the_bucket',
#   'croak',
#   'spell',
#   'tour',
#   'become',
#   'endure',
#   'break',
#   'cristal',
#   'fail',
#   'run_low',
#   'run',
#   'whirl',
#   'locomote',
#   'give_out',
#   'go_game',
#   'rifle',
#   'go_away',
#   'sound',
#   'offer',
#   'function',
#   'live',
#   'drop_dead',
#   'fit',
#   'go',
#   'pass',
#   'run_short',
#   'break_down',
#   'snuff_it',
#   'X',
#   'operate',
#   'exit',
#   'pass_away',
#   'perish',
#   'buy_the_farm',
#   'expire',
#   'Adam',
#   'plump',
#   'crack',
#   'hug_drug',
#   'depart',
#   'ecstasy',
#   'blend',
#   'work',
#   'conk',
#   'get',
#   'conk_out',
#   'live_on',
#   'get_going',
#   'decease',
#   'travel'],
#  'success': ['success', 'winner', 'achiever', 'succeeder'],
#  'fates': ['destine',
#   'designate',
#   'plump',
#   'fate',
#   'fat',
#   'fatten',
#   'destiny',
#   'fortune',
#   'circumstances',
#   'plump_out',
#   'flesh_out',
#   'fill_out',
#   'doom',
#   'portion',
#   'fatten_up',
#   'luck',
#   'fatten_out',
#   'lot'],
#  'gaps': ['crack',
#   'disruption',
#   'col',
#   'break',
#   'spread',
#   'opening',
#   'gap',
#   'interruption',
#   'breach'],
#  'discourage': ['deter', 'warn', 'discourage', 'monish', 'admonish'],
#  'reacting': ['oppose', 'react', 'respond'],
#  'poor': ['short',
#   'miserable',
#   'hapless',
#   'pitiful',
#   'poor',
#   'pathetic',
#   'pitiable',
#   'misfortunate',
#   'inadequate',
#   'piteous',
#   'wretched',
#   'poor_people'],
#  'sphere': ['welkin',
#   'field',
#   'vault_of_heaven',
#   'area',
#   'celestial_sphere',
#   'empyrean',
#   'firmament',
#   'arena',
#   'sector',
#   'sphere',
#   'sphere_of_influence',
#   'domain',
#   'heavens',
#   'orbit'],
#  'range': ['array',
#   'lay_out',
#   'grasp',
#   'swan',
#   'roll',
#   'stray',
#   'scope',
#   'rove',
#   'order',
#   'kitchen_stove',
#   'chain_of_mountains',
#   'graze',
#   'orbit',
#   'crop',
#   'cast',
#   'ambit',
#   'vagabond',
#   'drift',
#   'run',
#   'grade',
#   'image',
#   'pasture',
#   'tramp',
#   'cooking_stove',
#   'compass',
#   'range',
#   'range_of_mountains',
#   'rate',
#   'range_of_a_function',
#   'reach',
#   'wander',
#   'kitchen_range',
#   'straddle',
#   'stove',
#   'roam',
#   'chain',
#   'browse',
#   'rank',
#   'mountain_range',
#   'mountain_chain',
#   'ramble',
#   'place',
#   'set_out'],
#  'Convinced': ['positive',
#   'convinced',
#   'confident',
#   'win_over',
#   'convert',
#   'convince'],
#  'centralized': ['centralize',
#   'centralise',
#   'centralised',
#   'centralized',
#   'concentrate'],
#  'Isolated': ['apart',
#   'isolate',
#   'sequestrate',
#   'keep_apart',
#   'stray',
#   'quarantined',
#   'stranded',
#   'isolated',
#   'obscure',
#   'insulate',
#   'detached',
#   'disjunct',
#   'marooned',
#   'set_apart',
#   'sequester',
#   'set-apart',
#   'separated'],
#  'powers': ['tycoon',
#   'office',
#   'ability',
#   'index',
#   'big_businessman',
#   'exponent',
#   'superpower',
#   'business_leader',
#   'top_executive',
#   'force',
#   'power',
#   'great_power',
#   'might',
#   'magnate',
#   'powerfulness',
#   'mightiness',
#   'major_power',
#   'king',
#   'world_power',
#   'mogul',
#   'baron'],
#  'gain': ['derive',
#   'pull_ahead',
#   'gain_ground',
#   'attain',
#   'arrive_at',
#   'advance',
#   'realise',
#   'take_in',
#   'benefit',
#   'addition',
#   'win',
#   'bring_in',
#   'amplification',
#   'make',
#   'acquire',
#   'realize',
#   'get_ahead',
#   'gather',
#   'reach',
#   'earn',
#   'pull_in',
#   'clear',
#   'gain',
#   'hit',
#   'increase',
#   'make_headway',
#   'put_on',
#   'profit'],
#  'professional': ['master', 'professional_person', 'professional', 'pro'],
#  'cold': ['frigidness',
#   'frigidity',
#   'moth-eaten',
#   'insensate',
#   'dusty',
#   'common_cold',
#   'cold',
#   'cold-blooded',
#   'frigid',
#   'low_temperature',
#   'inhuman',
#   'coldness',
#   'stale'],
#  'realistically': ['realistically'],
#  'impulses': ['nervous_impulse',
#   'impetus',
#   'pulse',
#   'impulsion',
#   'nerve_impulse',
#   'whim',
#   'pulsation',
#   'momentum',
#   'pulsing',
#   'caprice',
#   'impulse',
#   'urge',
#   'neural_impulse'],
#  'rigid': ['unbending',
#   'set',
#   'stiff',
#   'fixed',
#   'inflexible',
#   'rigid',
#   'strict'],
#  'balance': ['residual',
#   'proportionality',
#   'rest',
#   'correspondence',
#   'proportion',
#   'Balance',
#   'balance_wheel',
#   'remainder',
#   'equilibrise',
#   'counterpoise',
#   'counterweight',
#   'equilibrium',
#   'residue',
#   'equipoise',
#   'Libra_the_Balance',
#   'equalizer',
#   'counterbalance',
#   'equilibrize',
#   'equaliser',
#   'Libra',
#   'residuum',
#   'symmetricalness',
#   'Libra_the_Scales',
#   'symmetry',
#   'balance',
#   'equilibrate',
#   'poise'],
#  'affect': ['touch',
#   'bear_on',
#   'impact',
#   'move',
#   'affect',
#   'feign',
#   'pretend',
#   'involve',
#   'sham',
#   'impress',
#   'bear_upon',
#   'dissemble',
#   'strike',
#   'regard',
#   'touch_on'],
#  'special': ['particular',
#   'especial',
#   'extra',
#   'special',
#   'exceptional',
#   'peculiar',
#   'limited'],
#  'themselves': [],
#  'later': ['later',
#   'afterwards',
#   'ulterior',
#   'recent',
#   'by_and_by',
#   'former',
#   'after',
#   'posterior',
#   'tardy',
#   'previous',
#   'afterward',
#   'late',
#   'subsequently',
#   'later_on',
#   'belated'],
#  'left': ['left',
#   'lead',
#   'leave_behind',
#   'left_over',
#   'pass_on',
#   'result',
#   'left-hand',
#   'go_forth',
#   'impart',
#   'pull_up_stakes',
#   'remaining',
#   'bequeath',
#   'go_away',
#   'leftfield',
#   'allow_for',
#   'give',
#   'left_wing',
#   'leave',
#   'get_out',
#   'exit',
#   'leftover',
#   'forget',
#   'will',
#   'left_field',
#   'go_out',
#   'left_hand',
#   'depart',
#   'leave_alone',
#   'entrust',
#   'provide',
#   'odd',
#   'allow',
#   'unexpended'],
#  'press': ['press',
#   'weight-lift',
#   'press_out',
#   'agitate',
#   'constrict',
#   'iron_out',
#   'crush',
#   'exhort',
#   'closet',
#   'weightlift',
#   'printing_press',
#   'contract',
#   'military_press',
#   'pressure',
#   'jam',
#   'urge_on',
#   'weigh',
#   'compress',
#   'entreat',
#   'crusade',
#   'iron',
#   'beseech',
#   'adjure',
#   'push',
#   'insistency',
#   'campaign',
#   'compact',
#   'insistence',
#   'squeeze',
#   'fight',
#   'wardrobe',
#   'pressing',
#   'public_press',
#   'bid',
#   'conjure',
#   'mechanical_press',
#   'urge',
#   'imperativeness'],
#  'prepare': ['develop',
#   'ready',
#   'prepare',
#   'set',
#   'organise',
#   'devise',
#   'cook',
#   'get_up',
#   'groom',
#   'educate',
#   'make',
#   'machinate',
#   'set_up',
#   'fix',
#   'gear_up',
#   'train',
#   'organize'],
#  'our': [],
#  'effective': ['efficient',
#   'good',
#   'effective',
#   'in_effect',
#   'in_force',
#   'efficacious',
#   'effectual'],
#  'however': ['nevertheless',
#   'however',
#   'still',
#   'all_the_same',
#   'even_so',
#   'withal',
#   'notwithstanding',
#   'yet',
#   'nonetheless'],
#  'becoming': ['seemly',
#   'becoming',
#   'go',
#   'comely',
#   'decent',
#   'decorous',
#   'become',
#   'get',
#   'suit',
#   'turn',
#   'comme_il_faut'],
#  'for': [],
#  'is': ['comprise',
#   'live',
#   'constitute',
#   'exist',
#   'be',
#   'represent',
#   'personify',
#   'follow',
#   'make_up',
#   'cost',
#   'embody',
#   'equal'],
#  'utilization': ['use',
#   'utilisation',
#   'utilization',
#   'employment',
#   'exercise',
#   'usage'],
#  'benefits': ['gain', 'profit', 'benefit', 'welfare', 'do_good'],
#  'free': ['liberate',
#   'barren',
#   'innocent',
#   'justify',
#   'give_up',
#   'rid',
#   'free',
#   'unloosen',
#   'discharge',
#   'resign',
#   'unloose',
#   'unblock',
#   'spare',
#   'relinquish',
#   'costless',
#   'loose',
#   'gratis',
#   'absolve',
#   'complimentary',
#   'liberal',
#   'unfreeze',
#   'devoid',
#   'detached',
#   'disembarrass',
#   'relieve',
#   'destitute',
#   'disengage',
#   'exempt',
#   'release',
#   'free_people',
#   'gratuitous',
#   'dislodge'],
#  'single': ['individual',
#   'I',
#   'undivided',
#   'exclusive',
#   'bingle',
#   'single',
#   'ace',
#   'unity',
#   '1',
#   'one',
#   'unmarried'],
#  'dearly': ['dear', 'affectionately', 'in_a_heartfelt_way', 'dearly'],
#  'too': ['as_well',
#   'overly',
#   'to_a_fault',
#   'also',
#   'besides',
#   'too',
#   'likewise',
#   'excessively'],
#  'government': ['regime',
#   'government_activity',
#   'governance',
#   'administration',
#   'governing',
#   'politics',
#   'authorities',
#   'political_science',
#   'government'],
#  'understanding': ['empathize',
#   'sympathy',
#   'reason',
#   'realise',
#   'understanding',
#   'savvy',
#   'apprehension',
#   'see',
#   'agreement',
#   'understand',
#   'discernment',
#   'sympathise',
#   'realize',
#   'translate',
#   'intellect',
#   'read',
#   'empathise',
#   'sympathize',
#   'interpret',
#   'infer'],
#  'all': ['all',
#   'whole',
#   'totally',
#   'entirely',
#   'altogether',
#   'wholly',
#   'completely'],
#  'Only': ['only_if',
#   'solely',
#   'but',
#   'just',
#   'entirely',
#   'solitary',
#   'alone',
#   'exclusively',
#   'only_when',
#   'simply',
#   'lone',
#   'merely',
#   'sole',
#   'only',
#   'lonesome'],
#  'changing': ['shift',
#   'switch',
#   'change',
#   'deepen',
#   'modify',
#   'exchange',
#   'transfer',
#   'alter',
#   'changing',
#   'ever-changing',
#   'convert',
#   'commute',
#   'vary',
#   'interchange'],
#  'members': ['member',
#   'fellow_member',
#   'appendage',
#   'penis',
#   'extremity',
#   'phallus'],
#  'nations': ['land',
#   'body_politic',
#   'Carry_Amelia_Moore_Nation',
#   'state',
#   'commonwealth',
#   'Carry_Nation',
#   'res_publica',
#   'nation',
#   'Nation',
#   'country'],
#  'often': ['ofttimes',
#   'oftentimes',
#   'often',
#   'frequently',
#   'oft',
#   'a_great_deal',
#   'much'],
#  'achieved': ['attain', 'reach', 'accomplish', 'achieve'],
#  'demand': ['demand',
#   'requirement',
#   'ask',
#   'exact',
#   'postulate',
#   'take',
#   'need',
#   'involve',
#   'necessitate',
#   'call_for',
#   'require'],
#  'firmly': ['steadfastly',
#   'firmly',
#   'hard',
#   'securely',
#   'firm',
#   'unwaveringly'],
#  'guide': ['lead',
#   'channelise',
#   'head',
#   'template',
#   'guide_on',
#   'maneuver',
#   'scout',
#   'manoeuvre',
#   'steer',
#   'manoeuver',
#   'conduct',
#   'run',
#   'pathfinder',
#   'templet',
#   'direct',
#   'draw',
#   'guide',
#   'channelize',
#   'take',
#   'pass',
#   'guidebook',
#   'usher',
#   'point'],
#  'decrees': ['fiat', 'decree', 'order', 'rescript', 'rule', 'edict'],
#  'supply': ['provision',
#   'append',
#   'furnish',
#   'supply',
#   'issue',
#   'render',
#   'cater',
#   'add',
#   'provide',
#   'ply',
#   'supplying'],
#  'surpluses': ['surplus', 'surplusage', 'nimiety', 'excess'],
#  'Technical': ['technical_foul',
#   'expert',
#   'technological',
#   'technical',
#   'proficient'],
#  'marked': ['note',
#   'pronounced',
#   'pit',
#   'tick_off',
#   'score',
#   'brand',
#   'scar',
#   'label',
#   'strike_off',
#   'tick',
#   'pock',
#   'cross_off',
#   'stigmatise',
#   'cross_out',
#   'grade',
#   'check_off',
#   'punctuate',
#   'mark_off',
#   'distinguish',
#   'marked',
#   'notice',
#   'differentiate',
#   'nock',
#   'check',
#   'set',
#   'mark',
#   'denounce',
#   'stigmatize',
#   'tag',
#   'strike_out',
#   'commemorate'],
#  'interrelationships': ['interrelation',
#   'interrelationship',
#   'interrelatedness'],
#  'creative': ['creative', 'originative'],
#  'yet': ['hitherto',
#   'however',
#   'withal',
#   'up_to_now',
#   'til_now',
#   'heretofore',
#   'notwithstanding',
#   'thus_far',
#   'in_time',
#   'so_far',
#   'still',
#   'even_so',
#   'yet',
#   'nevertheless',
#   'as_yet',
#   'all_the_same',
#   'even',
#   'until_now',
#   'nonetheless'],
#  'simultaneously': ['at_the_same_time', 'simultaneously'],
#  'this': [],
#  'dominant': ['predominant',
#   'dominant_allele',
#   'rife',
#   'prevailing',
#   'dominant',
#   'prevalent'],
#  'problems': ['job', 'trouble', 'problem'],
#  'lack': ['want', 'deficiency', 'miss', 'lack'],
#  'bureaucracies': ['bureaucratism', 'bureaucracy'],
#  'leaders': ['drawing_card', 'loss_leader', 'leaders', 'leader', 'leadership'],
#  'issue': ['matter',
#   'effect',
#   'write_out',
#   'outlet',
#   'egress',
#   'come_out',
#   'result',
#   'subject',
#   'go_forth',
#   'government_issue',
#   'issuing',
#   'publication',
#   'number',
#   'yield',
#   'payoff',
#   'come_forth',
#   'way_out',
#   'offspring',
#   'emergence',
#   'return',
#   'bring_out',
#   'military_issue',
#   'takings',
#   'supply',
#   'take',
#   'proceeds',
#   'outcome',
#   'upshot',
#   'progeny',
#   'put_out',
#   'consequence',
#   'exit',
#   'cut',
#   'issuance',
#   'event',
#   'make_out',
#   'issue',
#   'release',
#   'publish',
#   'emerge',
#   'topic'],
#  'human': ['human_being', 'homo', 'human', 'man'],
#  'especially': ['peculiarly', 'specially', 'especially', 'particularly'],
#  'struggle': ['clamber',
#   'scramble',
#   'fight',
#   'struggle',
#   'contend',
#   'shin',
#   'skin',
#   'sputter',
#   'battle',
#   'conflict',
#   'shinny'],
#  'how': [],
#  'cohesion': ['coherency', 'coherence', 'cohesion', 'cohesiveness'],
#  'around': ['just_about',
#   'about',
#   'more_or_less',
#   'round',
#   'approximately',
#   'or_so',
#   'roughly',
#   'close_to',
#   'some',
#   'around'],
#  'domestic': ['domestic_help', 'house_servant', 'domesticated', 'domestic']}

# %% [markdown]
# Una *matriz semántica* está compuesta de *vectores semanticos*. El vector semántico es el concepto que representa el *eje de la seleccion* para una palabra w en el mensaje.
#
# Una breve explicación del eje de la selección:
#
# >Seleccion:
# >La selección estudia qué palabra selecciona un hablante entre las palabras existentes de la lengua, más o menos similares y hasta cierto punto equivalentes. La selección se basa en la sinonimia o antonimia de una palabra. En otros términos, en su semántica

# %% [markdown]
# Por ejemplo, veamos cuál sería el vector semántico de "provincial":

# %%
provincial = jakobson.vector_semantico("provincial")
provincial
# Out:
# ['bucolic', 'peasant', 'provincial']

# %% [markdown]
# ¿Cómo se calcula el vector semántico? A través de *Wordnet*.
#
# >WordNet® is a large lexical database of English. Nouns, verbs, adjectives and adverbs are grouped into sets of cognitive synonyms (synsets), each expressing a distinct concept. Synsets are interlinked by means of conceptual-semantic and lexical relations
#
# los requerimientos del para el vector semantico eran que:
# - representaran relaciones entre ideas
# - fuera lo suficientemente extenso para buscar una gran cantidad de palabras, pertenecientes a distintos corpus.
#
# Por eso se selecciono Wordnet.
#
# Internamenta, Wordnet lemmatiza los palabra "provincial" y la compara con otros lemmas segun criterios linguísticos que más tarde podrían extender la funcionalidad de  `jakobson`. Lo más importante de un vector semántico, es que procura capturar una 'idea', más allá del mero lemma.

# %% [markdown]
# Ahora, luego de formar la matriz semántica para un mensaje, `jakobson` calcula la *matriz de uso*. Para cada *vector semántico*, se produce un *vector de uso*. El objetivo del vector de uso es representar --valga la redundancia-- el uso de cada componente de del vector semántico. ¿Cómo podríamos representar el uso de cada palabra? Asignandole un número. Se utilizó un modelo de Bag of words. Veamos un ejemplo:

# %%
from nltk.probability import FreqDist
#bag of words para el m
fd = FreqDist(corpora_referencia)
provincial_u = jakobson.vector_uso(provincial, fd)
provincial_u
# Out:
# [0, 0, 1]

# %%
printfd["bucolic"]

fd["peasant"]
fd["provincial"]
# Out:
# 1
