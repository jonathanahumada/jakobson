# %%
from jakobson import results
# Out:
# 2022-04-24 16:14:43,934 - numexpr.utils - INFO - NumExpr defaulting to 4 threads.

# %%
import matplotlib.pyplot as pyplot
# Out:
# 2022-04-24 16:14:46,627 - matplotlib - DEBUG - matplotlib data path: /home/jaumaf/miniconda3/envs/tesis/lib/python3.9/site-packages/matplotlib/mpl-data
# 2022-04-24 16:14:46,636 - matplotlib - DEBUG - CONFIGDIR=/home/jaumaf/.config/matplotlib
# 2022-04-24 16:14:46,640 - matplotlib - DEBUG - interactive is False
# 2022-04-24 16:14:46,641 - matplotlib - DEBUG - platform is linux
# ...

# %%
import seaborn as sns

# %%
c1 = results.leer_muestra('c1','./resultados')

# %% [markdown]
# # Ajustes gráficos

# %%
sns.set_theme()
sns.set(rc={"figure.figsize":(15, 12)})
pyplot.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
pyplot.xticks(rotation=45)
categorias = sns.barplot(x="categoria", y="metafora_n", data=c1,  palette="ch:r=-.2,d=.3_r")

# %%
metacategoria = sns.boxplot(x="metacategoria", y="metafora_n", data=c1,  palette="ch:r=-.2,d=.3_r")

# %%
facet  = sns.FacetGrid(c1, col="categoria") 
facet.map(sns.histplot,'metafora_n')

# %%
grouped = c1.groupby('metacategoria',as_index=False)

sns.barplot(x="metacategoria", y="metafora_n", data=grouped.mean(),  palette="ch:r=-.2,d=.3_r")
# Out:
# <AxesSubplot:xlabel='metacategoria', ylabel='metafora_n'>

# %%
def guardar_grafico_resumen(df,nom,feature):
    grouped = c1.groupby('metacategoria',as_index=False)

    res = sns.barplot(x="metacategoria", y=f"{feature}", data=grouped.mean(),  palette="ch:r=-.2,d=.3_r")
    res.get_figure().savefig(f"./resultados/graphs/{nom}_{feature}_meta")

# %%
guardar_grafico_resumen(c2,"c2","metonimia_n")

# %%
c2
# Out:
#                         categoria     metafora  metonimia     w metacategoria  \
# 0                       reportage   869,205.24     234.00  2277   non-fiction
# 1                       editorial   777,241.54     252.30  2200   non-fiction
# 2                         reviews   978,095.23     242.32  2415   non-fiction
# 3                        religion   831,466.36     234.21  2213   non-fiction
# 4                skills & hobbies   833,209.38     237.43  2279   non-fiction
# 5                    popular lore   965,391.19     270.54  2369   non-fiction
# 6                  belles lettres   863,139.75     279.74  2289   non-fiction
# 7                   miscellaneous   873,426.71     302.27  2416       neither
# 8                         learned   912,477.03     241.60  2189   non-fiction
# 9                 general fiction 1,025,249.85     243.06  2440       fiction
# 10  mistery and detective fiction   959,584.20     231.74  2370       fiction
# ...
